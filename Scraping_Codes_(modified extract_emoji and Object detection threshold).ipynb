# %% [markdown]
# # DMI Course

# %% [markdown]
# ## Data Scrapping

# %% [markdown]
# Install the appropriate ChromeDriver from stable options available at https://googlechromelabs.github.io/chrome-for-testing/
# From the Stable verions list find the currect one for you operating system.
#
# On Windows:
# Method 1: Using System Information
# Press Windows + R, type msinfo32, and press Enter.
# In the System Information window, look for System Type:
# x64-based PC → 64-bit
# x86-based PC → 32-bit
#
# On macOS:
# Click the Apple logo in the top-left corner.
# Select About This Mac.
# Click System Report (or More Info → System Report in macOS Ventura or later).
# Under Hardware Overview, check the Processor Name:
# Intel Core i3, i5, i7, i9, M1, M2, M3 → 64-bit
# Intel Core Duo, Core Solo → 32-bit (rare on modern Macs)
#
# Download and unzip the file.

# %% [markdown]
# # Warning: Avoid using your primary Instagram account for repetitive attempts if it is valuable to you, as it may be restricted or disabled due to scrapping (unusual) behavior detection on the platform.

# %%
# !pip install requests
# !pip install selenium

# !pip install opencv-python
# !pip install numpy
# !pip install matplotlib
# !pip install pandas
# !pip install opencv-python torch transformers pandas pillow
# !pip install timm
# Out:
# Requirement already satisfied: requests in d:\software\anaconda\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software\anaconda\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\software\anaconda\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software\anaconda\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software\anaconda\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: selenium in d:\software\anaconda\lib\site-packages (4.29.0)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\software\anaconda\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in d:\software\anaconda\lib\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in d:\software\anaconda\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in d:\software\anaconda\lib\site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in d:\software\anaconda\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in d:\software\anaconda\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in d:\software\anaconda\lib\site-packages (from trio~=0.17->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in d:\software\anaconda\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in d:\software\anaconda\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in d:\software\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in d:\software\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in d:\software\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in d:\software\anaconda\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in d:\software\anaconda\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in d:\software\anaconda\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in d:\software\anaconda\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: opencv-python in d:\software\anaconda\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in d:\software\anaconda\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: numpy in d:\software\anaconda\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in d:\software\anaconda\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\software\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\software\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\software\anaconda\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\software\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in d:\software\anaconda\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\software\anaconda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\software\anaconda\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\software\anaconda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\software\anaconda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\software\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in d:\software\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\software\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\software\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\software\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\software\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\software\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: opencv-python in d:\software\anaconda\lib\site-packages (4.11.0.86)
# Requirement already satisfied: torch in d:\software\anaconda\lib\site-packages (2.6.0)
# Requirement already satisfied: transformers in d:\software\anaconda\lib\site-packages (4.49.0)
# Requirement already satisfied: pandas in d:\software\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: pillow in d:\software\anaconda\lib\site-packages (10.4.0)
# Requirement already satisfied: numpy>=1.21.2 in d:\software\anaconda\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: filelock in d:\software\anaconda\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\software\anaconda\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in d:\software\anaconda\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in d:\software\anaconda\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in d:\software\anaconda\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in d:\software\anaconda\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in d:\software\anaconda\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\software\anaconda\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in d:\software\anaconda\lib\site-packages (from transformers) (0.29.1)
# Requirement already satisfied: packaging>=20.0 in d:\software\anaconda\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\software\anaconda\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\software\anaconda\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in d:\software\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\software\anaconda\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in d:\software\anaconda\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in d:\software\anaconda\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\software\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\software\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\software\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\software\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in d:\software\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\software\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software\anaconda\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\software\anaconda\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software\anaconda\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software\anaconda\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: timm in d:\software\anaconda\lib\site-packages (1.0.15)
# Requirement already satisfied: torch in d:\software\anaconda\lib\site-packages (from timm) (2.6.0)
# Requirement already satisfied: torchvision in d:\software\anaconda\lib\site-packages (from timm) (0.21.0)
# Requirement already satisfied: pyyaml in d:\software\anaconda\lib\site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in d:\software\anaconda\lib\site-packages (from timm) (0.29.1)
# Requirement already satisfied: safetensors in d:\software\anaconda\lib\site-packages (from timm) (0.5.3)
# Requirement already satisfied: filelock in d:\software\anaconda\lib\site-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\software\anaconda\lib\site-packages (from huggingface_hub->timm) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in d:\software\anaconda\lib\site-packages (from huggingface_hub->timm) (24.1)
# Requirement already satisfied: requests in d:\software\anaconda\lib\site-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\software\anaconda\lib\site-packages (from huggingface_hub->timm) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\software\anaconda\lib\site-packages (from huggingface_hub->timm) (4.11.0)
# Requirement already satisfied: networkx in d:\software\anaconda\lib\site-packages (from torch->timm) (3.3)
# Requirement already satisfied: jinja2 in d:\software\anaconda\lib\site-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: setuptools in d:\software\anaconda\lib\site-packages (from torch->timm) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in d:\software\anaconda\lib\site-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\software\anaconda\lib\site-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: numpy in d:\software\anaconda\lib\site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\software\anaconda\lib\site-packages (from torchvision->timm) (10.4.0)
# Requirement already satisfied: colorama in d:\software\anaconda\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\software\anaconda\lib\site-packages (from jinja2->torch->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software\anaconda\lib\site-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\software\anaconda\lib\site-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software\anaconda\lib\site-packages (from requests->huggingface_hub->timm) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software\anaconda\lib\site-packages (from requests->huggingface_hub->timm) (2025.1.31)

# %%
# Import necessary modules
import requests # For sending HTTP requests to the website to download the image data
import os # For file operations and directory creation 
import time # For adding delays
import pandas as pd # For creating and manipulating DataFrames 
from selenium import webdriver # For automating the browser 
from selenium.webdriver.common.keys import Keys # For simulating keyboard keys like RETURN, ENTER, etc.
from selenium.webdriver.support import expected_conditions as EC # For waiting for certain conditions to be met before
#proceeding like an element to be clickable or visible. ec and WebDriverWait are used together to wait for a certain
#condition to be met before proceeding. And is different from time.sleep() as it waits for a certain condition
#to be met before proceeding and is different from WebDriverWait.
from selenium.webdriver.common.by import By # For locating elements by their attributes like class, id, tag name, etc.
from selenium.webdriver.support.ui import WebDriverWait # For waiting for a certain condition to be met before proceeding like
#an element to be clickable or visible and to set the maximum time to wait for a condition before throwing an exception. 
# And it is different from time.sleep() as it waits for a certain condition to be met before proceeding. And is different
# from expected_conditions as it is used to set the maximum time to wait for a condition before throwing an exception.
from selenium.webdriver.chrome.service import Service # For creating a Service object with the path to the chromedriver
#executable to control the Chrome browser
from selenium.common.exceptions import TimeoutException # For handling exceptions when a certain condition is not met within
#a specified time

# Specify the path to the chromedriver executable, which is used to control the Chrome browser 
chromedriver_path = "C:/Users/XSIU/OneDrive/Groningen(online)/MADS/2a/digital marketing intelligence/chromedriver-win64/chromedriver.exe"
#"C:/Users/Ali/Downloads/chromedriver-win64 (1)/chromedriver-win64/chromedriver.exe"

# Create the ChromeOptions object
options = webdriver.ChromeOptions()
options.add_argument("--lang=en-US")  # Force Chrome to start in English

# Creating a Service Object
service = Service(executable_path=chromedriver_path)

# Initialize the WebDriver with the specified options
driver = webdriver.Chrome(service=service, options=options)


# Open Instagram
driver.get("https://www.instagram.com/")








# Find and interact with the username and password fields
username = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='username']"))) # Wait for the username field to be clickable, css selector is used to locate the element by its attribute which is the name attribute in this case
password = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='password']"))) # Wait for the password field to be clickable
username.clear() # Clear the username field
password.clear() # Clear the password field
username.send_keys("y.tao.2@student.rug.nl") # Enter the username
password.send_keys("**********") # Enter the password



# you want to submit the form or click the login button
password.send_keys(Keys.RETURN) # Press the RETURN key after entering the password













# Waiting and handling the first "Not Now" pop-up
# try and except are used to handle exceptions when a certain condition is not met within a specified time
try: 
    not_now_button = WebDriverWait(driver, 20).until( # Wait for the "Not Now" button to be clickable for up to 20 seconds
        EC.element_to_be_clickable((By.XPATH, '//div[@role="button" and text()="Not now"]')) # Locate the "Not Now" button by its role and text using an XPath expression which is a query language for selecting nodes from an XML document or an HTML document and is different from CSS selectors which are used to locate elements by their attributes like class, id, tag name, etc.
    )
    not_now_button.click() 
except TimeoutException: # Handle the TimeoutException if the "Not Now" button is not found or not clickable
    print("First 'Not Now' button not found or not clickable.")

# Adding a slight delay before looking for the second button
time.sleep(2)






# Waiting and handling the second "Not Now" pop-up
try:
    not_now_button2 = WebDriverWait(driver, 20).until(
        EC.element_to_be_clickable((By.XPATH, '//button[@class="x1i10hfl xjqpnuy xa49m3k xqeqjp1 x2hbi6w x972fbf xcfux6l x1qhh985 xm0m39n xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x18d9i69 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1q0g3np x1lku1pv x1a2a7pz x6s0dn4 xjyslct x1lq5wgf xgqcy7u x30kzoy x9jhf4c x1ejq31n xd10rxx x1sy0etr x17r0tee x9f619 x1ypdohk x78zum5 x1f6kntn xwhw2v2 xl56j7k x17ydfre x1n2onr6 x2b8uid xlyipyv x87ps6o x14atkfc xcdnw81 x1i0vuye xn3w4p2 x5ib6vp xc73u3c x1gjpkn9 x5n08af xsz8vos" and text()="Not Now"]')) # Locate the second "Not Now" button by its class and text using an XPath expression, using xpath to locate the element by its attribute which is the class attribute in this case
        #EC.element_to_be_clickable((By.XPATH, '//button[@class="_a9-- _ap36 _a9_1" and text()="Not Now"]')) # Locate the second "Not Now" button by its class and text using an XPath expression, using xpath to locate the element by its attribute which is the class attribute in this case
    )
    not_now_button2.click()
except TimeoutException:
    print("Second 'Not Now' button not found or not clickable.")
    
    
    
    
    
    

# Please note that extracting 50 posts from each influencer may not be successful in a single attempt.
#  It is recommended to run the code one time for each influencer instead. 
# Remember to update the name of the Excel file to avoid overwriting it.
influencer_urls = [
    "https://www.instagram.com/alexandrasaintmleux/",
    "https://www.instagram.com/maralafontan/",
    "https://www.instagram.com/bellahadid/",
    "https://www.instagram.com/badgalriri/",
    "https://www.instagram.com/realbarbarapalvin/"
    #,
    #"https://www.instagram.com/sydney_sweeney/"
    #"https://www.instagram.com/victoriabeckham/"
]

# List to store image URLs and likes, date, time, caption
data = []

# Create directory to save images
path = os.getcwd() # Get the current working directory
save_dir = os.path.join(path, "scrapping_dmi") # Create a new directory named "scrapping_dmi" in the current working directory
os.makedirs(save_dir, exist_ok=True) # Create the directory if it does not exist








max_scrolls = 50  # maximum number of scrolls to perform
posts_needed = 50 # number of posts needed per influencer

# Process each influencer URL
for influencer_url in influencer_urls:
    driver.get(influencer_url) # Open the influencer's Instagram profile
    time.sleep(5)  # wait for the page to load

    anchors = [] 

    for _ in range(max_scrolls): # Scroll down multiple times to load more posts 
        # If we already have enough posts, stop scrolling
        if len(anchors) >= posts_needed:
            break # Exit the loop if we have enough posts
        
        # Scroll down
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") # Scroll to the bottom of the page, 0 is the x-coordinate and document.body.scrollHeight is the y-coordinate, we use 0 for x-coordinate to scroll vertically
        time.sleep(5)  # give time for new posts to load

        # Find <a> elements whose href attributes contains "/p/" (Instagram post links)
        anchor_elements = driver.find_elements(By.CSS_SELECTOR, "a[href*='/p/']")  
        
        # Get the actual href for each element, href is the attribute that contains the URL of the link
        new_hrefs = []
        for elem in anchor_elements:
            href = elem.get_attribute("href")
            # Make sure it's a valid post link
            #if href and ".com/p/" in href:
            new_hrefs.append(href)

        # Add only those that are not already in `anchors`
        for href in new_hrefs:
            if href not in anchors:
                anchors.append(href)

        # Keep just the first 50
        anchors = anchors[:50]

    print(f"Found {len(anchors)} links for {influencer_url}")
    influencer_name = influencer_url.rstrip("/").split("/")[-1] # for example, "https://www.instagram.com/mrbeast/" becomes "mrbeast", rstrip() is used to remove the trailing slash and split() is used to split the URL by the forward slash and get the last element which is the influencer name
    
    
    
     # Follow each post link and extract details
    for index, a in enumerate(anchors): # Iterate over the list of post links, enumerate() is used to get both the index and the value of each element in the list
        driver.get(a) # Open the post link
        time.sleep(10)  # Wait for the page to load completely

        # Find the number of likes
        try:
            likes_element = WebDriverWait(driver, 10).until(
                EC.visibility_of_element_located((By.XPATH, '//span[contains(@class, "html-span xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x1hl2dhg x16tdsg8 x1vvkbs")]'))
            )
            likes = likes_element.text
        except Exception:
            likes = "Not found"

        # Find the date and time
        try:
            datetime_element = driver.find_element(By.XPATH, '//time[contains(@class, "x1p4m5qa")]') 
            date_time = datetime_element.get_attribute('datetime') # Get the datetime attribute of the time element
            if date_time:
                date_time = date_time.replace('Z', '')  # Remove the timezone part
        except Exception:
            date_time = "Not found"
            
 




        
        # Find meta data
        try:
            metadata_element = driver.find_element(By.XPATH, '//meta[@name="description"]')
            metadata = metadata_element.get_attribute('content')
        except Exception:
            metadata = "Not found"
            
            
            
        
        
        
        
        
        # Download the image
        try:
            image_element = WebDriverWait(driver, 10).until(
#                 EC.visibility_of_element_located((By.XPATH, '//img[contains(@class, "x5yr21d")]'))
                EC.visibility_of_element_located((By.XPATH, '//img[@class="x5yr21d xu96u03 x10l6tqk x13vifvy x87ps6o xh8yej3"]'))
                
            )
            image_url = image_element.get_attribute('src') # src attribute contains the URL of the image to be downloaded
            print(image_url)
            image_name = f"{influencer_name}_image_{index}.jpg"
            image_save_as = os.path.join(save_dir, image_name) # Save the image in the specified directory with the image name

            # Download the image
            img_data = requests.get(image_url).content # Get the image data from the URL
            with open(image_save_as, 'wb') as handler: # Open the file in write binary mode and write the image data to the file
                handler.write(img_data) 
            print("Image downloaded successfully")
        except Exception as e:
            print(f"Failed to download image: {e}")
            image_name = "Not found"

        # Append the data 
        data.append({
            'Influencer': influencer_name,
            'Post URL': a,
            'Image Name': image_name,
            'Likes': likes,
            'Date Time': date_time,
#             'Caption': caption,
            'Metadata': metadata
        })

# Close the webdriver
# driver.quit()

# Create a DataFrame, sort by date and time in descending order, and save to Excel
df = pd.DataFrame(data)
df['Date Time'] = pd.to_datetime(df['Date Time'], errors='coerce').dt.tz_localize(None) # Convert the 'Date Time' column to datetime format and remove the timezone information
df = df.sort_values(by='Date Time', ascending=False) # Sort the DataFrame by 'Date Time' in descending order 
df.to_excel('scrapping_dmi.xlsx', index=False)  

# Display the DataFrame
print(df.head())
# Out:
# Second 'Not Now' button not found or not clickable.
# Found 50 links for https://www.instagram.com/alexandrasaintmleux/
# https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/482730091_18487379947000657_6915046173090325670_n.jpg?stp=dst-jpegr_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuaGRyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AF_Jm_U-8hYVNyp2YOlxgLuh3ygsKsqreppT39MbPlzK0aA6eE1kFrZX96rtnzcCwk&_nc_ohc=laeuZfZx6OcQ7kNvgF-ReY4&_nc_gid=ff4008f9a9d4429783d020421e8acb44&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU4MzAxOTQ4MTY5MzM0MjM4OQ%3D%3D.3-ccb7-5&oh=00_AYF4_kzeO0xysHlRL2yZSydwNJmAq3RfnJidEC_1oOQOxg&oe=67D65575&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/480090416_18483943522000657_8286689979165986087_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3MzAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AGd21cGU7mTdU-dka_dwztbXMKjJ2zzTVzuue-3HjzHh861t7PymvHOIbMKsNrA0jg&_nc_ohc=PnHvkrjsYRQQ7kNvgEvxYd3&_nc_gid=3316ce03473e42e0b3c252db8f77c85a&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2OTQ0NTgyODcwOTA0MjA0MA%3D%3D.3-ccb7-5&oh=00_AYGSEJlSC8qHmCGy0tipFWKOayb7SgHNQc7UCfXoLFV9lw&oe=67D66F5D&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/479495524_18483348217000657_4294343868689241629_n.jpg?stp=dst-jpegr_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuaGRyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AFGAao1g-ge9RYfZlxNltOl8fYWlDBbsYgt4-aupQ_mu8H-Jv6ol0dTXpT6XP9jXIg&_nc_ohc=vStO7_RhhvIQ7kNvgFQT5Ra&_nc_gid=04a77dc54205468781b23b3dbc554b09&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2NzIyMjIyOTkyNzcxMjE2MQ%3D%3D.3-ccb7-5&oh=00_AYGi3IAt8yt1kqu0aQZyjQSTNr26TsKTX7rqajK7ycXXEQ&oe=67D683BB&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/477213975_18483003358000657_4259177641994667476_n.jpg?stp=dst-jpegr_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuaGRyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AE5b_PKZKL4dRW9AJ5-HcRYkMfudooDyzxJp267FeXEZyJT2QweclGcQsPLPOJA5PA&_nc_ohc=to6SvVBWslYQ7kNvgFJCkQh&_nc_gid=7173a09b24a04c2f906e548d16d57ec8&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2NTc3NzQ0MjE5NTAyODkzMQ%3D%3D.3-ccb7-5&oh=00_AYEQFVFyUKJyeU-ACADbj2YnCsCg4UnWIFswH7dRwTUUcQ&oe=67D66D5F&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/476918130_18482809942000657_7826133736931760455_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AFXxrR4MMMi56tuQorsiCRpGZ8IRuVDbtySh_dkr8rA9WU5i3M8mrWtxHEBvdCmBCc&_nc_ohc=tTnlmWRMSXoQ7kNvgHuOe9U&_nc_gid=17e24be4ac914d88a4799963220d47a7&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2NTAyODc5NzE1ODk5MDk5Ng%3D%3D.3-ccb7-5&oh=00_AYGzJDiuDlDF-iBMayE7_4hNJLYjmLUukwsYrhwphZgVdg&oe=67D6503E&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/476295892_18481600555000657_1286796220211450399_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AEhB_Ilrm8Kgvd0Wcj07Pz_HRXh437IQ_eMFy_THCEJ47gWz_nCwwT1cvH22P-sgOY&_nc_ohc=-BDZGl4l-tsQ7kNvgGYHTi_&_nc_gid=aaa626473e14406d9dc6f8166e654d48&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1OTkwNjk1MjE0NjU2ODkwNA%3D%3D.3-ccb7-5&oh=00_AYHAb4EBnp2pbWANTiU9E16bkd8NGD4FeUDR5felxJdNkg&oe=67D67D03&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/474525108_18481408786000657_4056176983189644336_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AEmqnk6ctv-UavorUWcmjzb4zUBHqygstKmodYEtWHV3_TZzVJWNoB0ydjbHb0Qzog&_nc_ohc=swz43ovfRWAQ7kNvgHSnKSD&_nc_gid=b24e3b28a5204e0c957b0b7875e51f44&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1OTExNjQ4ODgzNDI0MDc4Mg%3D%3D.3-ccb7-5&oh=00_AYE0e_EHP5s0qsgdXmrAsW-5MgjelB37HaEvTiDoE4OAPg&oe=67D669FE&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.2885-15/475891608_18481294522000657_1350460467057998451_n.jpg?stp=dst-jpegr_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuaGRyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AHW4J00kWqpZ873X8lvjBffrbuKIvAtGr1R27i9fwaeEEjfmfx9pe8keOVbOzzhX0Y&_nc_ohc=R0o6Zb11OhkQ7kNvgFThRq8&_nc_gid=10fe8f5aed884cea836ca95aefcf34be&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1ODYxMjUzNTE3MjMzNzIzMQ%3D%3D.3-ccb7-5&oh=00_AYHmo2Hr0z7WZEgjk171KsCs-0mI4EMN_Dxun3x5Am4MfA&oe=67D6718D&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/472372624_937063094688317_2695809020210639286_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE2NDQuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=105&_nc_oc=Q6cZ2AGOsadzu8fZ4ZZU1-TTGPqaO4hMLYAJCcDHAcaYP_fg_P8U6uwrVgOViVOhan8yH6k&_nc_ohc=CGS6EjRu07MQ7kNvgG-Rn4Z&_nc_gid=73c5803d46454f11a4de57f82a240e43&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUzNTQ1MjE5NzEwMzg0ODA1MA%3D%3D.3-ccb7-5&oh=00_AYG0ZsORA7zt5vDSA2KesCCeR7ZacO05O9q6yVtW9qzqJg&oe=67D66672&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/471823146_927767869462046_7004151899582243621_n.jpg?stp=dst-jpegr_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3MzQuaGRyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=102&_nc_oc=Q6cZ2AGDfNJllwuDoEeLf_pmBgF4J7gnsJMw4AAEhvkdKobyuhmFigmg3eZRqdhjM904rM4&_nc_ohc=pCHVmnOdI70Q7kNvgHs0H8A&_nc_gid=b6c4a0b251b1420e9ba811b068c08977&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUzMzE0NzI5MTM2MTUyODkzNA%3D%3D.3-ccb7-5&oh=00_AYGPhpDL3vuBrr2CMiH3co4rfMJizYFZ9YO9cV1jue_mog&oe=67D669FF&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/471806677_587368160821620_1213201137687116451_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE2ODYuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=100&_nc_oc=Q6cZ2AEU31rNcAWYzVEmlioygYHIiePGx-IIL4GnSxZ4SmnbecJVd6LyYXRiOlptJOgFZWI&_nc_ohc=04nHkArxVHkQ7kNvgE-3dM2&_nc_gid=37d9a8d7b2094cafbee2080fe1cba3d5&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUzMTc1OTUwNzUxMDAyMDQ3MQ%3D%3D.3-ccb7-5&oh=00_AYHE_HU-e7kJk45aqLYc1eNc7pugmm0jd0yBnz98K6rAAA&oe=67D671F0&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/471574199_1300115154331794_4214157725027426362_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMDQyeDEyMTQuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGAFz3vRt8_3AjGRZJZi0RerKicWAaFzY3TABi1X-cHGzWWUKLsJ3LGfDxClzTnA4Q&_nc_ohc=NlW7-b9lQC8Q7kNvgFxBxJW&_nc_gid=d9e1e80387014256accf51a5a77a0aaa&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUzMTAxNDAzMzk3ODk1MzE5MA%3D%3D.3-ccb7-5&oh=00_AYG3vz5J4F4f4zVHgHTjqte6S4nYk0PkduOAiR_laHd8EA&oe=67D652DD&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/471522781_1810390253032574_8798255820964128238_n.jpg?stp=dst-jpegr_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuaGRyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=102&_nc_oc=Q6cZ2AHO7cZkgGqf0enDlZMr_Mo0ln3iCKGDWvet25lhWHRU3MhN3hv-RBTli5x1TuSgV54&_nc_ohc=gFsnqq3j7GQQ7kNvgEafRGu&_nc_gid=6f6a5950cabc4885928c0596bfe7c3f8&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUzMDI2NjE1MzM3OTA5MzU4MQ%3D%3D.3-ccb7-5&oh=00_AYFqdiSAFqssjV8URO4W23BaJKtywOO18NMfzEisHxLokg&oe=67D65C4F&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/470162817_487436230492023_2959554424589950382_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi45OTV4MTE5NS5zZHIuZjI5MzUwLmRlZmF1bHRfaW1hZ2UifQ&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=103&_nc_oc=Q6cZ2AHn3Yai0psfMszj89er1OE3IDkxuR3at8F1uPBPXMTx9QE3H2DoG-pkOdTYi6o5FV8&_nc_ohc=ZMO-50RTJ2AQ7kNvgG2PQ87&_nc_gid=f6006aa78d0546ed9382f90c79257f11&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUyMzgyODg0NjYyOTY3MjMyNg%3D%3D.3-ccb7-5&oh=00_AYEGHaEq51fYuuUJkKzRAGJ2iO7FPEz_u1YZ2Ayu-EEZ2A&oe=67D67B18&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/469653077_1753636315470154_2499100549685787618_n.jpg?stp=dst-jpegr_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuaGRyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=110&_nc_oc=Q6cZ2AF2y_5FUTBLDY0ktZ-zP7eQjgpddfsNnnIA-HpBKs9ea24fXqiwOhS35H29xmDg9AA&_nc_ohc=GPa_H1eJsyoQ7kNvgEMwkpQ&_nc_gid=934b388ccb1b4c7983c45af972d967a8&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUyMDAyNDE2NTc1NTIwMjY0Nw%3D%3D.3-ccb7-5&oh=00_AYEqW-nbXRu57Da5i7lv6ZBrAgUh0rQQ3zOFmYj5uSdlTA&oe=67D6742E&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/469107864_434068169761500_827391630159592542_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=100&_nc_oc=Q6cZ2AEasNCN2nQViOFURyUqvORwIf58LNq4bto58fZ-Y2yMqv84TTqT7Wu4cCJIlbhMUQE&_nc_ohc=FzDp2yAbe-MQ7kNvgFdqRKC&_nc_gid=e2f1c77e3c414c19a5851908839fd2dd&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUxNDI4OTA0NDkyNDcwODAyNw%3D%3D.3-ccb7-5&oh=00_AYEcZ8DAXP6cwQdbRdBSEzUkXKlrf3whpLNuEM3gmhuKVQ&oe=67D6549F&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/468337906_1096233558749143_1346585294290274974_n.heic?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE2NDguc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=107&_nc_oc=Q6cZ2AFgbBsq-dS19-rTbC2X7Wl5CDcg3Y-igQIq7lFVcNPkK1IhdQJM0r2ujKkdxQzJhlw&_nc_ohc=JV-Khtt7uywQ7kNvgEO59Bd&_nc_gid=488a7ee2a007466d8f33991e24dcfd65&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUwOTIyNDMyODk3NDg2MzQ4OQ%3D%3D.3-ccb7-5&oh=00_AYELPUl56lG9g54oyJmtncr0a2amTKwIHv8ha1g9_LtJtw&oe=67D6715C&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/467513376_1217569366623457_1633282151763973117_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AGSDuQolFHaRVdCG1INUttjQRLr3BTkU2s0f5NSPpBtfUTswXFTsTQpx8tKKY79IC8&_nc_ohc=tNy94QAeCfEQ7kNvgFU7NsX&_nc_gid=46746fa183594f12935e98d386cb5c41&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUwNjQ0MzMxMDk3MzgxMjIyMw%3D%3D.3-ccb7-5&oh=00_AYF15fkt-u5Gstk2NlHWNdiTjfpl2PSO0P5QyTs110zMow&oe=67D670FF&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/467304342_965659538720948_5671732362210679973_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=108&_nc_oc=Q6cZ2AEUtcaUyg8D8qu64My1JCyuS5grzTiwZv7qE34AE42ff7ZoTvakVaY0emVGsbukHtg&_nc_ohc=VHK8rqmnZOkQ7kNvgEV9eCH&_nc_gid=8b00864af1fa4a65b7a250dad18d1fc6&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUwNTU4ODQ3MzYzMzY4OTcxNQ%3D%3D.3-ccb7-5&oh=00_AYFWBovuMl5G4JgDxqLhc6PpGMBgpgcWhDbNeUJAoJSzfg&oe=67D6684F&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/466057447_1100364054903268_176311411980594189_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE2NTcuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AGjfdzZnSfQU_DSo8B3fHF2UnABvD399QldLFJr6LjE7EvtpALlceuX3cBgUCUVKBU&_nc_ohc=36dUtDTKJHAQ7kNvgH9Aw8v&_nc_gid=ce091ed24e6747559548af76a4ba1452&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUwNDE0NzgwMjMwOTY4ODEzOQ%3D%3D.3-ccb7-5&oh=00_AYF0F2BjxO3QTbqwF5Y3GQNS45kmx87ZBgsH2dTSTL9HyQ&oe=67D65087&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/466671901_1265199044618367_1223583458897202246_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=103&_nc_oc=Q6cZ2AGSl1LCeqWiBf2H8g4WHZLvkX5ckQWYranfvp1IQwqY0sf92mJ3b_a4zfzGrGHLXXE&_nc_ohc=M76A5d2fn80Q7kNvgH5hmmg&_nc_gid=7b6331d7f29543319fcaa17f6127a6d6&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzUwMzQxNTg4OTg1MjgzOTY1NA%3D%3D.3-ccb7-5&oh=00_AYGbbRFsEO9-_l62F5vNwi80JM0TLg-Bsh-_TR7QIxfdgA&oe=67D65469&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/465231965_1858418898301460_6973506411655154194_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMDIweDEyNjEuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=108&_nc_oc=Q6cZ2AHm_y1Xk0nDVSD_zez1vqyxmcF0gJIvqyKdwTMcraAdhMDkYCrZrc__Ui-AA2ipndI&_nc_ohc=GoKILFmXM0oQ7kNvgFv3Clu&_nc_gid=9041001b4ee94f178b4563c9df986732&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ5NDcwNzk1ODA0NzIyOTkzOA%3D%3D.3-ccb7-5&oh=00_AYFMsGfi1isragU4IbDVzbko9BGbDjt21qBBmXIG0mf9zQ&oe=67D68573&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/464820490_1229202248319059_7163060701643297820_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=111&_nc_oc=Q6cZ2AEMc-DemVu59TGFpwz-m9wOcxAYxMADWoMCrm15foC2qWngvPxanZh_pK44fLmFp7A&_nc_ohc=7aGmgTLC760Q7kNvgHS1h2N&_nc_gid=732bf82236224dc3a5b7956308a73f9a&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ4ODk0MDY2OTMwMzI4MTM1MA%3D%3D.3-ccb7-5&oh=00_AYFTv8iiTGbGQ_gNTm1osdkxLFtzLYBXkYJDGPjzeS211Q&oe=67D66509&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/464671690_1049844516613187_3847791422714645594_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3ODAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=111&_nc_oc=Q6cZ2AFW2JoKVmI692-ZPY11s3ZqV6zmxRfyR792kySzn7dNlaRb3uBfmPeb05lqxDeopvU&_nc_ohc=pwd5GwJ8K7gQ7kNvgEQbXZF&_nc_gid=3c7e473dae9046388114a76ee305a342&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ4NzA1NTgwNTA0Njk1ODA3MA%3D%3D.3-ccb7-5&oh=00_AYE59TSQqW4425B5f6kxnL7IN2y5vpSR6rXrtvg8h0OdlA&oe=67D67C7B&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/462952551_8285592308230184_232587104504971606_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDIuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=108&_nc_oc=Q6cZ2AG9HSsIQ_d5LwQyiDf1hUCy8BnvH3mqRcoLOibFNdVzk9uOdIck9X77DhTXwgcpDVM&_nc_ohc=JnYguLnvelAQ7kNvgFW1gNJ&_nc_gid=066d47a1460240568810f1dbba8510ab&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ3NzI0MjAxMzgzMTc5ODUzOQ%3D%3D.3-ccb7-5&oh=00_AYFRnssRuX8Sde3vWEOReoWeA3IM9WWD4Be5zlpLQ3-gBg&oe=67D6734B&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/461015220_1685848998880895_782552945399692907_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=111&_nc_oc=Q6cZ2AERmfHmVwEN73vyse0ZeAy5osUKGRt_E4cMapcpGiXRgyW4KcR5NjwQVf5NXrupg-k&_nc_ohc=H8YUT9poC3MQ7kNvgHz8bxa&_nc_gid=15645f4f19a3442180762dbd7bfebd25&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ2MTg4OTQ1MDQ0OTg3MDI1Ng%3D%3D.3-ccb7-5&oh=00_AYGvYUvXUqoYmgzzL4bB0BycOI-O--_pl6TgooLH9dnk8g&oe=67D66256&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/457169320_478421175068309_8755014204052503287_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE0NTguc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=105&_nc_oc=Q6cZ2AFWx4-sialLng0sbJzvDuDRmhKQqgSVhIY_j6JcZsW2798ZMeoCZ6BYidYu_WfI9r4&_nc_ohc=mJ_yD-LyevIQ7kNvgHCjYqm&_nc_gid=77576aed74bc422ba1725b1bb0c3e137&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ0NDAzODAzMzg0MDY3MjQzNg%3D%3D.3-ccb7-5&oh=00_AYExRavQIf_A4YVxOQdwBXMYr49RF0hBv-MlrafBJqVnaA&oe=67D67E97&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/456615799_1613683492822902_5536085673874812688_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGnFNTZ96eu5et0QPuwCG6OSF0gR10ZoHyLy1-1I-qSjoQG6XxM9WCKOrCpbg51bdE&_nc_ohc=ekpdYtIH_AsQ7kNvgErDn-f&_nc_gid=7708ac90a08f4c079ca17442a8d150ce&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ0MDM3NzUyMzE5MDM3ODM0OQ%3D%3D.3-ccb7-5&oh=00_AYHnXCW1Y8AtffSR2o1g1aLSt8_-TW73LumqMbKlE241ig&oe=67D66703&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/456258963_1024519126038690_6203942063610741085_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AHtNpSwAqzc_RtdjoPN28rfYidW6j1x0aV7zQT5AuvsGSbN1XkNgEkXfoeyYNKnjic&_nc_ohc=trwyQO97G7oQ7kNvgHc0tbq&_nc_gid=c40562db264e430288efe11b19573469&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQzOTcxMTQ0NjIwMTgyNTc0Nw%3D%3D.3-ccb7-5&oh=00_AYHJGw3ax4B_yVzDsxmVDND18boe64k6e2JzOmgV69fY1A&oe=67D67BDC&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/455872348_1129954358849544_4731666569220791165_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=100&_nc_oc=Q6cZ2AFyoN4LTW1R0zOMlMA7zzuxj7aGqa_9TPROy47q4AFYxDkMZ5dWVqc9hCi4g7Dq0sA&_nc_ohc=wabpsqFqzNAQ7kNvgGmBFkP&_nc_gid=6eb8a860cf4e4d46b94c914ddd1a8ab4&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQzNjcyOTEyMTE1NTQ1NzkwMQ%3D%3D.3-ccb7-5&oh=00_AYF5Owlu_mPSkzRD8yaV-rWPYcBL6D21ZcqBj7lm7ACA3w&oe=67D67F2D&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/455127452_872709764315140_6574154375225861679_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AEIm-IFKngSyNfD_9f_4K17XSsh9doo2UlbnwWAZjV_OlybNSqjQsC6KO71QFYdz0I&_nc_ohc=2jd9DIf_twcQ7kNvgFW1IFv&_nc_gid=d814676cf42e4f6eb87268672653f252&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQzNjQ3MTk5MDU2OTk1MjI5Ng%3D%3D.3-ccb7-5&oh=00_AYEvCNymrI8416Y-K0l0koCseAse35OVl20P69e-32ItQQ&oe=67D66442&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/455568028_1312430759732445_4879630956290346176_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=109&_nc_oc=Q6cZ2AG4JHvhkjW3XTcuK_0F69n_p_bZ4V1UGQMGMGLOE7h9Xtd5HXuSyq160QYGGZip_qU&_nc_ohc=5cVFOTTpVfAQ7kNvgHtEs1F&_nc_gid=44299853731a42c2a142e059763a1d54&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQzNTEyNzk3NTk0MTUyMTczMg%3D%3D.3-ccb7-5&oh=00_AYFQgjLcwBzct1WRXhOb9votaQ5yEFiBfKxVe29boax30w&oe=67D66689&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/455141464_1016851653367816_2929889889979917592_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AF7zbg5frqErvqQNLEXixmamLw0wTL5XSUfrtpVDmBk7ScT0sieklkKZPfZ6ROgUtA&_nc_ohc=_oolZcsqSIsQ7kNvgHbX64o&_nc_gid=b7e2ca63f717498faf1b198affba1b11&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQzMzA3OTk3MDgxOTQ2MTk1Mg%3D%3D.3-ccb7-5&oh=00_AYH3QBJAFnWipNVeTgKmguL95gRNTrld9LAWB-a8cdLjgQ&oe=67D6795E&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/454520213_8254422617953605_432960978928739349_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=109&_nc_oc=Q6cZ2AHH6NHIvSBC3e8vFt0zbFWS8n5c4bqgG1WVd8hfBLVlM8natignSkRlW_Zhy0XhBbI&_nc_ohc=ERHpUxT219MQ7kNvgEqo-QS&_nc_gid=6d86559674154b48af3338e039e27d68&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQzMDg1MjgzNzYxNTE2MTQyNg%3D%3D.3-ccb7-5&oh=00_AYFyDlHG0cMxGqJkEaXJxKPt36wOLmChewd9uZt7MPCYeg&oe=67D65C43&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/454492962_2859355270879082_8113470481361018855_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=102&_nc_oc=Q6cZ2AGpYaEF4noa5g9ihniOsG4z1Mt3FQSBvFHInirVwUGA6WvHf0H4agvuGe_AJijlDrg&_nc_ohc=phZABOU5K4sQ7kNvgF0j7Eo&_nc_gid=d1df7a4114cb419dbd3758789363938e&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQyOTQ2NDYzNTIzMDk5NDg3MQ%3D%3D.3-ccb7-5&oh=00_AYH_8ReEia7icnoSkNV5unrle1oFgmFTimCAHLH-RqQGCg&oe=67D67AD2&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/449884220_1224683968708311_3431050368959425963_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTYuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=103&_nc_oc=Q6cZ2AHk3oBxiQDfDIBrW64zbEo1dHfxvl4mi1LoyRpILBR05L2GziTM94vkakcq5Zp8r6w&_nc_ohc=wtqU_yr0p8sQ7kNvgEs9vGu&_nc_gid=23c9d30e23154917bedb9ef7b981d73f&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQyODY1NTg2NjUxNTA2MDA4MA%3D%3D.3-ccb7-5&oh=00_AYGPwpnBCw93cXpEDR_B20nPlhaM_LVD5p1utn9QzqlIyg&oe=67D66FDB&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/452578132_1266142167684718_5888781835736943180_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=110&_nc_oc=Q6cZ2AEB9Cv61NX18zLbZJ6JF2Motj5kgek6ntXaml09hlr1Ev5-HLGW6SFm8iR-vSIqtho&_nc_ohc=jS9olCYu6ykQ7kNvgGxqKmc&_nc_gid=e6881a140e7346c6bee31c0a61b25117&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQxNzgyNjcyNTk2ODUyODA1OA%3D%3D.3-ccb7-5&oh=00_AYFP5I7AFL0kAipLY-BZBhfLc9ixzJN_N2ssV4zYNE83hw&oe=67D65DE9&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/452122247_1250063569312611_1694891916959605725_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE2NTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=103&_nc_oc=Q6cZ2AGFG_lXi-Fm5YnK4nLrSGCJvW0el46_mdJ_VyRWjpewo2fguV3qYHUmg4QKenYxYOs&_nc_ohc=nkJzOH8nxtAQ7kNvgFi4hmK&_nc_gid=d845d4b266864cf3b3f1f3b14d2da411&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQxNjY4OTgyNzkwODk0NDc2Mg%3D%3D.3-ccb7-5&oh=00_AYHzbPYfx3MXnf5WujQ2848ot6OAABQ4CoSQ1ylsJsqi4Q&oe=67D687A9&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/451081316_768058101911334_7456453116915327581_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AHvBP5LhQkfxebVdYx38HLD9kitJDfDEoUAQ1hTbIk6b3BKcfy0F0GiytgWQIVvmiM&_nc_ohc=rJvT19RgvsYQ7kNvgEg5T_K&_nc_gid=03e4ec52698d4fe6ba8464b532640ce5&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQxMTU3NTI4MzQxNTk0MDU4MA%3D%3D.3-ccb7-5&oh=00_AYFuErR8MTeT9q_VbmFk44UysminYCyZn64L1xo_k2Hqsw&oe=67D66686&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/450945306_1217633056253700_1875871398632651247_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=100&_nc_oc=Q6cZ2AElylBAx8g6H1RXJPOLoo07f5LJ6vO0cpEImup-I0-J4ti6YJmNe9LkMTF1huB3bBc&_nc_ohc=-qtt9HGX2kcQ7kNvgF7MnhC&_nc_gid=8d1b96259df3457cb896bd9a51648b2a&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQxMDc0NjA4NTk0MDA4NDA4Mg%3D%3D.3-ccb7-5&oh=00_AYHbh3sdKcMkaGY9T8IcAqhYg57FKobukf18ykiUb-8LdA&oe=67D669DB&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/451087569_2220421704965676_3441641764433252596_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=100&_nc_oc=Q6cZ2AE2tkfk5AVU7Osxx95iCg1rIqtXHBR7v_lclg5Q2QpOgi4wjYzp7SeesfXAfiF5TyE&_nc_ohc=q611pOwrKRcQ7kNvgGG3wgu&_nc_gid=8443889f596b4b2d9ebfa63e533bd1ea&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQxMDY5OTUxMjY1NjcyODQxNQ%3D%3D.3-ccb7-5&oh=00_AYFLGBkXk6x91qEvzMt4U_m30RPigjBcOCfpd5yNN1R6tQ&oe=67D671D9&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/449139342_318262394673154_4387171380499236930_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=110&_nc_oc=Q6cZ2AFK-MdkAM3IEkXDpxnlf536YoJOr4bx448vunhgFbF03YKg94G-y6Wyd5ftQOR6EUc&_nc_ohc=6neRuD_NlEMQ7kNvgGxhwXB&_nc_gid=826c0a1036da44d4863d83ba4e969fe7&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM5NzU5OTY2OTIxNzY5OTA2MQ%3D%3D.3-ccb7-5&oh=00_AYGz1smYp4d2P1W5WoWx3r2uzYK-VP2u_O2wtXoYDAZy-w&oe=67D66F87&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/448854883_865208368902882_300288001487120130_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE0OTEuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AEeHuOZFJqwbONwZIuzm6rop1tEaRJI1-X0zdcL5mgHiKTVRegXGHSkR6KVsdslNvA&_nc_ohc=F9HZZieC-aIQ7kNvgEVj8-f&_nc_gid=b73734d62fa64f558f008776e8276a43&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM5Njg3ODQ5MTczODE0MDE0MQ%3D%3D.3-ccb7-5&oh=00_AYFXbFcbwD7CCxkKqJ-2pdL925_04vHlOA1HNEWhks6PFQ&oe=67D682C5&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/446115340_1937668280023345_250443131197286581_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3MjYuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AH9xbJkjjOI8OlKBiwC6KZzaHOo30PAtos0hjH9Vfdg322a9peoLZn5XksAoUtbmqo&_nc_ohc=CrHa4jTAn38Q7kNvgEiU0Fn&_nc_gid=d9e315419fbd42b9afcd37ada9991e09&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM3NTk5MzI4ODI3MTExNjI3OA%3D%3D.3-ccb7-5&oh=00_AYGZxzHU2RVX9CF6wgoNstGtJWNJN3QiG0t4Zyw514Ufrg&oe=67D659C8&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/446229924_1618923631983677_8463606293561533589_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTYuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=105&_nc_oc=Q6cZ2AEBwcxLE6Ckp1w-AMQ-LeKSL9tRmJN6I3aDaSQv7TKXH7bURcSnUkuzruH71swpPjc&_nc_ohc=u-BtY3LhlPoQ7kNvgH7WthK&_nc_gid=fa9703ca18a640bfbd614660d20773c4&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM3NTk5Mjg4NjMzOTQwNTA1MA%3D%3D.3-ccb7-5&oh=00_AYGK_rKIrN1DrbCXEAB5yfatfcyyAz-WXsdQ5mMd-uXIjw&oe=67D67ACA&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/443900728_7985965248137570_3435467538137264358_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=102&_nc_oc=Q6cZ2AEGmsZzNcmZUxJX9kwQ4REJnj3eArBD6I5a7N4McGJyuGR-fy9O8yC5MONLiu8VjFo&_nc_ohc=D3PJVosWTOIQ7kNvgG28RKH&_nc_gid=093038a764404698a6507964937096be&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM3MDY2MzM4Mzg5ODY3ODA5OA%3D%3D.3-ccb7-5&oh=00_AYEWfF2sgMKKchpZb9ziNKtW9rain3f4u7LLEYSBP_YWaQ&oe=67D6748D&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/436367841_997962021716761_4324831797850158128_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTYuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AHUw92j8APzCYiVC5yMKcrEXvn1eJRk5UH4eEiYFEye8u0F7k7rD5mck9zkzQaoLj0&_nc_ohc=5azxrtDoAAoQ7kNvgG2YepH&_nc_gid=c622957bf31f4d1caa6be306bc33dd1c&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM2NDIyNzM4MjM0MzI2MjQ1OA%3D%3D.3-ccb7-5&oh=00_AYGrbGGwkgxoCdulu6PN81eK80KucfiXcZr5FjKvdYBiMw&oe=67D670BA&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/440048177_950542066371961_4534532974377923414_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AGPJxYyGjpTAt-0IEg7Z0tLy22kLWguD4dimZX4XhAc3oPDAOZN4sHrHYLCkb5qAPk&_nc_ohc=_5QcCDO5D5cQ7kNvgGWmfDe&_nc_gid=08a9f1f993df4bc9af687ce0ffc99bac&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM1MDY3ODAyOTMzNDY0OTEzOA%3D%3D.3-ccb7-5&oh=00_AYGXWGMjPU84IOG1x6CSdjQlu9zdEWuKF3Vw8_4JoE98_Q&oe=67D685C7&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/434769273_1091930818726206_5869135342693487413_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AEXcUdp1iFJqEO6p39RLTH4SFyKquwxRDJXnkFduidhajvgWiW2p0lArJNWVUeRUA4&_nc_ohc=jMJr5-8P4VkQ7kNvgHzrBcA&_nc_gid=0b7e2824e8ee4e1caaaa19bf02a513ef&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMzNTAzNjQ2NzcyNTIxMTQxNQ%3D%3D.3-ccb7-5&oh=00_AYE0dTsKW3SE2Q78SbJYJ5KKJtnLzWX7GhtSesAWgd5GsA&oe=67D677A9&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/434728577_1581362756029551_3114473916666466645_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=103&_nc_oc=Q6cZ2AEfSys-a-GWqgA5fwCLodOL9Ecrwc2nJPGVaK2-gyQSMdBboybkrDte1cmw4uvhWLY&_nc_ohc=dO5K-j_tNUAQ7kNvgE52YoT&_nc_gid=ea15630d25e046528285f89b561a8c8d&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzMzNDQ3NTI2MzMxNTM0MDg0Ng%3D%3D.3-ccb7-5&oh=00_AYHuC1gd9uhh67VCEB_iIJ3qKtrj5JrRG8IsKk6NUAI4LA&oe=67D675A2&_nc_sid=fc8dfb
# Image downloaded successfully
# Found 50 links for https://www.instagram.com/maralafontan/
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/483562154_18490413592007934_1618987678925821304_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMDgweDEzNTAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGXstx9EA_Gzw-Fm5e_8J3WBl_Zmvk_IDDrtsQjiWdqa5zsGFgPJNL4UNM-hf-olvA&_nc_ohc=RO0YT1J48wQQ7kNvgHxs7H8&_nc_gid=b989516ac94049c59d0b3a6ed0b6871b&edm=AONqaaQBAAAA&ccb=7-5&ig_cache_key=MzU4NTM4MzA0NDcyNzc2NTE3NA%3D%3D.3-ccb7-5&oh=00_AYH2EeKldCRSGm9K4E0mpf7VZBAXBMN4bRmGuNMK-0xJsQ&oe=67D66F34&_nc_sid=4e3341
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/483310798_18490143370007934_6063397627306414362_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AHxuLar1XRQbg6JZWNK4CEL2iaDiUZ2RAI8KyGZipZuH9LneoNaKAAWcRvpS1RduPA&_nc_ohc=11BwMUabRBAQ7kNvgG2Lb29&_nc_gid=aa548ed82599478182c8cb1d16d9c01f&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU4NDU3MTIwNDIxMzE0NTIyOA%3D%3D.3-ccb7-5&oh=00_AYGZzni7hNeIK2EfWrH4qryIyIb-dGUh7ZVIc43eN_EkEQ&oe=67D680F1&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/483256187_18489701578007934_8104697891401881745_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AEH-UGK5eGtSW39WSANpPwRGWNPjq35nLHwU7ptDwHgig6vMEPf7IviCy4jP7AYGRw&_nc_ohc=5rcpoMIHnFEQ7kNvgFdFNKZ&_nc_gid=901bfdda17464796a17759c03c3ce95b&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU4MzA5MDg3MzE2MDk3NzUxNg%3D%3D.3-ccb7-5&oh=00_AYFryX69ub2T9Zrrp1JP72o6xEpXKUHb6Dk29CRISypCFA&oe=67D686FE&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/482747003_18489521071007934_7286079027546747416_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AE7aE3V3BsL5ppC_wHbR-ZPlfXRuvRPwFZnBaOC25T5r_7u8eK2PEji7FxrJYkeoCY&_nc_ohc=4zdIHH7M2j0Q7kNvgHdq8BW&_nc_gid=51d69f8731a047a5b01bdbbe8763d8e1&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU4MjQzMTAzOTI5MDA3NTAxOQ%3D%3D.3-ccb7-5&oh=00_AYF_9QTq20VNh0G79F1byFJunQgH2Z7GWtmHG2DdOwCaOg&oe=67D65694&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/482804345_18489117589007934_1157279115210825638_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AFFoDjxWrD5WetpZ7YWLt7u3Ca3I_gwLDIBF2__fdxorZNvZSqVcemgOE_IwKuDATY&_nc_ohc=am_7PR-lOrwQ7kNvgFBlYbF&_nc_gid=9c96737d329e4433804ab71f4713a383&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU4MDk2MzU3MzkzNDkxNDkwNg%3D%3D.3-ccb7-5&oh=00_AYHieasCA_34yV4VlEknzc00I_tDhXMNcVqdKGwPRSDhBQ&oe=67D687AC&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/482709562_18488923174007934_6705088927211164892_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTguc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AFoeznMN1aJS_D2sFHNtmFPbnRK-D_MWZL0n0MNW-53aQfOKl8orIZs2OETxPN9gu0&_nc_ohc=3nupxQoARsMQ7kNvgGuwUsD&_nc_gid=2b9a29e51ed9472aa34254654ce5d328&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU4MDI1MjIyNzM4NzA2ODE4Ng%3D%3D.3-ccb7-5&oh=00_AYE5YTeAmI86Hp8lEmzljC3dCCd7qy45suum9b1li7gb5w&oe=67D684F2&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/482457605_18488717920007934_7957966512626562047_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AEEbgRG2-GPVi1bHG5_0e06_chri96IeixrFbYHiJQ0UgClYNkHTpqvQyqp5eh1Mp8&_nc_ohc=x8MX09ZfIQ8Q7kNvgFW0H6U&_nc_gid=a7db9c9367474cf68bb5a41c3f862795&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU3OTU1NzY1NTc5NTQyOTYwNw%3D%3D.3-ccb7-5&oh=00_AYHLFUj4MDunEyh37AgZp2rYuf-MmAT4fgksvcyAZeu-UQ&oe=67D67BAD&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/482110127_18488519422007934_639236862251439630_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AEdiFpQnLlu6FGYsXwar5tyAFhIqWRX7svMIqxATf7zTc-3ObwhDicmAXRxfeNGoLw&_nc_ohc=yneXzBBeLgQQ7kNvgFLhfj7&_nc_gid=fee683dfe72f4936964dd02b15de6587&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU3ODgyNzAyMDczODk5NjUyNA%3D%3D.3-ccb7-5&oh=00_AYHAIcE3r_7892AZsHb7Ma2SlQHG36hH96b67wuEBzXL9A&oe=67D67742&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/482293161_18488326102007934_8800634281856962689_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AHeh1bd0IiE4riKNc776UO3799YZkW69PSRoXQ5nX0Q147Q-KSc2YLNv5wUWlv6WNc&_nc_ohc=4piuh4JqnQgQ7kNvgGObLeW&_nc_gid=1aa485e3127145d0863cfd972c9d5a67&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU3ODA4MjI3MzA2NTc5MTg3Nw%3D%3D.3-ccb7-5&oh=00_AYFH4MSTnMoUdY_6wKcV1o9qX6hzAh-gnjFK3h_2pXMRRg&oe=67D659E3&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/482085553_18487791709007934_6233218085325896703_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AFmkL5SpoXQu58ecoQ1jMD4noRPQq6M5NroU-8R8MDG3mosRz5FXkHNXR5YgB_euLg&_nc_ohc=6Lpo-_b0CZMQ7kNvgFNVc_4&_nc_gid=ab01cd912c5044b4b3b99de71a754f95&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU3NTkzMTY0Njk3ODE5NTcxMg%3D%3D.3-ccb7-5&oh=00_AYGQ-sU4UfYgIrQcTamRWNl1lo6MStXoA0uTRGo3dqg5Uw&oe=67D66B28&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/481574095_18487581184007934_1235815181599842362_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AFD8gDy25PF47mwxbRI9GCmtpuPErkmJwqkG5S6tguV_aMQ1lsiQgV79iRPOSKzCMw&_nc_ohc=7JnT-xb4jcsQ7kNvgGqtBkv&_nc_gid=210152e7083c4d1b87c43e729be315e8&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU3NTExOTU5MTQ4ODUxNjY5Mw%3D%3D.3-ccb7-5&oh=00_AYFn5oCA32IgVC5ZoXTjFBQEv1MFswWCnepaILtckH5Yeg&oe=67D66CF4&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/480888017_18486850252007934_2502558745541057980_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGwZ9XkJC_7EUZh1bIUmg6JZQ5BzZ4qkqevdaQZjTKEjOSEj6EZNsbDzoiDW8lk1ow&_nc_ohc=QmAy_PnlbfsQ7kNvgFQkeuj&_nc_gid=03d8dc8f416a49f0805f7d40a619d8a3&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU3MjI1NjE5ODg3NjQ2MjAzMA%3D%3D.3-ccb7-5&oh=00_AYGIMYGoyLBfGFglvrkWzWN5tblVgSXT0gyn9rqi9CH_Bw&oe=67D67FE9&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/480476204_18486696799007934_8743777835852470791_n.jpg?stp=dst-jpegr_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuaGRyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGdcKbO-wj48b9SY5rvDj-oxSfsqCmeNATnedourU-sOPmkerKNmLSV_bV049KOVIw&_nc_ohc=AMPbTUL3sM0Q7kNvgF4v-F3&_nc_gid=e7aa44a6b8324da9b92996771d09fcd3&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU3MTYwMzI0ODg0Nzg3OTI5NQ%3D%3D.3-ccb7-5&oh=00_AYEKokg593HmWQDflAZlBbic-NfbbQVRUK_IrhIm_-jJhA&oe=67D65F2B&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/480069116_18486504562007934_1973544477967221003_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AFo13ZHC-t5479WULHMO-41bUcKTASJl2JgUwPuTgsoFnkllrJkYSrcijC5MnfcN8o&_nc_ohc=B8MDGMjlj-EQ7kNvgFP8hQY&_nc_gid=6f5b5abdccda4656930e22a525d5b9f8&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU3MDgyMTQzODMyNDk1MDUxMg%3D%3D.3-ccb7-5&oh=00_AYHYy9d_VG7t4WTg_Y6KBxpJBwlHRozCTHZxhmk3ZHmLVg&oe=67D674C9&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/479903845_18486161809007934_1706644623825819587_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGNPD82Kwzw2Pc_gah31e5QxywRrf2D1Md2QUjsgMsvP0uGrcM6XD1CJsfVCJmpSBE&_nc_ohc=GsQIIeYHEvUQ7kNvgEEjs6X&_nc_gid=e9d89c85e8d44a34850f7febcf8768ef&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2OTQxNzA3NDk1MTk5MjMxMw%3D%3D.3-ccb7-5&oh=00_AYEAGkE61yRuihXytTTsECGMw07bPEh3jYIYOWCzGyfSLg&oe=67D68375&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/479904527_18485953549007934_3406448264970075666_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGvn8vUuvf9pTvlRuhNsbYnhjsX7CPTdVRGI4anFMJqMkvDK8D8K3XdM4j2rWgW66k&_nc_ohc=jroprj7lRCQQ7kNvgFIjnbs&_nc_gid=43ff7772e979494ea73f9004ac626f02&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2ODY0ODA4Njc5ODYyNTQ0OQ%3D%3D.3-ccb7-5&oh=00_AYF2a65AMXKYGpFVSff16ebjUjOuZ8b_BikxeWqiP6ZvsA&oe=67D66EED&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/479516790_18485736034007934_8353577364349897421_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AEmxEMHsQk1Kid8pCfZSVGrlS2AHivM_FF5iGqyvoPVQSrNFlvj6YXHwAd6c3X0hNA&_nc_ohc=Rhiu6UJ6fokQ7kNvgHIK70K&_nc_gid=0daf903b1898476bb3dbb597e5d0897f&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2Nzg2NTEwNDI2OTY1NjgyOQ%3D%3D.3-ccb7-5&oh=00_AYHsTCJw4YHDcaR0LnWbPslnaPk82AZTfTQVkPgvqk0Vig&oe=67D66DA5&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/476875363_18485391187007934_342220416738141808_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi45NjN4NzIyLnNkci5mNzU3NjEuZGVmYXVsdF9pbWFnZSJ9&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AFimFFPe-qZ38nZkZGHrCxj7VXXJaBEorP72mPqyWshJfVHuUnuwS-R5AsRFY5Q8k4&_nc_ohc=j1JjRrOkU0YQ7kNvgFjN8o-&_nc_gid=a5b5a93ac71e406784661aecbd41df11&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2NjQ2MTQxNzA2MDE3OTY3MQ%3D%3D.3-ccb7-5&oh=00_AYHBV9S-UJcadDzk85CWMiObhylf99BzYAtKvFCHvzknFA&oe=67D665AE&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/478500052_18485222365007934_6707389218749762525_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMDY3eDEzMzMuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGBPYMkMOG03lc7pdeFz7BIly3jum27tj7_3MFdRn0noMYqUG6ZlolQu0Ia81CRyRw&_nc_ohc=COgA5loO6UkQ7kNvgEICU8a&_nc_gid=3cb3ddcc1fcd42a6ac497f3be0cba3f0&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2NTczNjkzMTU5NDk0NDkzMg%3D%3D.3-ccb7-5&oh=00_AYGw7IAFaXhKmz_AcvHNj-JbrbkUq8VRjSeooF3K_XL19A&oe=67D66768&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/476931419_18484688413007934_3884931344945198439_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AG-4CLiLDzOsx0hxBo-rOaYl-mPwKUjVFiSP3VPCbTwGtDHh3MdXyb15M4eDaxOoP0&_nc_ohc=yNcJ-ib-YOgQ7kNvgHrwbKK&_nc_gid=f33f260d400b494da9e7206964116264&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2MzU1NTI2NTgwMzk0NTA4OQ%3D%3D.3-ccb7-5&oh=00_AYHJy-7ys4mHj0pWWlO4lkG4to8RngrJjY4biUWHqUF-nQ&oe=67D652ED&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/476245317_18484135951007934_7650064937658654825_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AFM-6D_3M2OrdNWTYsWegwzowLnySSDsLlvZvbiGFp0huyEpTictgmUgTZU4k3QUHU&_nc_ohc=DsOxa6hcDPEQ7kNvgHykGMY&_nc_gid=e6db4f3ad3f54989bd4ded7f34c15c01&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU2MTI2NzMxNjQ0MTUwMzM1NA%3D%3D.3-ccb7-5&oh=00_AYFh2rlesVndiS-Dhb9QVjbMg03YftCdCsSd0LGTKM0xpA&oe=67D681A2&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/475829010_18483476698007934_1846301349843286292_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMDgweDEzNTAuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGbuar3cf6QuaTjnkEmoEnaFQERtAQynb6TBiyNHppHE2IXMKhxCTMjhlCbbRKbO8c&_nc_ohc=bonU8Z0rOggQ7kNvgGfJhYF&_nc_gid=5f38495b94134be3bdc4977ae56db508&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1ODUwMzkyOTI1NjA1MjI3Mg%3D%3D.3-ccb7-5&oh=00_AYHRWemjgzYmrr1NXvqwkEA0HRmUtvMkYgDFHTIKKfM1ZQ&oe=67D68360&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/475695379_18483151507007934_22506857361447125_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AHWdyfZKfTrRIs2TlwPS-yszjLPoNjmcqptNT0zJbf6yWzMX1xjEOwKTevLASTvbig&_nc_ohc=xKUIj86_rBgQ7kNvgEx1sSj&_nc_gid=25440a1eb71c4d7c88a7a6e3b7fb5915&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1NzA4MjQ0MjQwMzA3ODI0Ng%3D%3D.3-ccb7-5&oh=00_AYEJLt7IEORKaFLWw6m9SN5AhmrN5lGBN2sShkBMAvldtA&oe=67D67949&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/475337530_18482836798007934_1392545702911020492_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AE5w8NR7NsEgK8a95MVttFoxMsa7YrCy6uqJGs7_Yw6INDCm7pBcP1J_niEQumgt_M&_nc_ohc=BOhVoKo_Zd4Q7kNvgHSU18j&_nc_gid=22d2a8bbc61a461ebec0b40e63a5cf48&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1NTU3NzYwMjAyNzkxOTMyNA%3D%3D.3-ccb7-5&oh=00_AYFjSjhgAC5sAacchu50ikbAGmOebqwj6KVawDjpLuE8Ow&oe=67D682CB&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/474003336_18482315995007934_8226467913687238738_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AF6c0lJeHOjG7FctthzU6yeUSxvC4nZwwkGedzQrDer2qrDB_msjXYWR0kOrTU_01Q&_nc_ohc=twXKcNVzWQwQ7kNvgGCC9XU&_nc_gid=bf95127675264ebe8b023bfd4af08338&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1MzM4NzYzNTA4MDExNjEzNg%3D%3D.3-ccb7-5&oh=00_AYHv6qF6tVmmPLId_QPF2qUFujEcbSMTz6aUcHSjoLp3FA&oe=67D67E50&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.2885-15/474837929_18481983142007934_9215682532665913738_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmY3NTc2MS5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AGeVhSP_lO83ORWNYkbE3LSXZJx1rZYzXTJ3ucl8i54rsPPStDuoT-NHCNDoOdC0mA&_nc_ohc=xnIbRDxGcnEQ7kNvgH5EWrb&_nc_gid=11cb4765c71d499ca5d032e0d12e016e&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1MTk2MzU5OTg1MDU2NTYyOQ%3D%3D.3-ccb7-5&oh=00_AYE0H64rCD1pUQRM6UdHhuhZ_HVvjizaOIBC5xMedjvRDQ&oe=67D679BE&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/474595408_964085565315160_4155357799828830460_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMjg0eDE2MDUuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AFGjkEJnXzDGYXvSDTxx8wqBbZ_9RbFgdm75fHeseMaDFyr0TWf8zrpNqGMAthcsUk&_nc_ohc=_4wBQ8bfqRUQ7kNvgH6p7ZP&_nc_gid=8e363258360141bc90ce69008e2a2da6&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzU1MDQ5NDk4MzE1NDA2ODE5Mw%3D%3D.3-ccb7-5&oh=00_AYGuBzYBvZoEciTxZZfLyESvR8GlRoVpH-LWEPfQvjF1OA&oe=67D656C0&_nc_sid=fc8dfb
# Image downloaded successfully
# ...
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/461526963_1190625355380628_2828621537821788818_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3NTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AHZhaomse265o954VW-ZmiulDr7LZ7j2ZG6GPo-jzldEo9FleqVe8G6Bg2NKZuYjrg&_nc_ohc=h6MW3f1aDOUQ7kNvgHqYzGW&_nc_gid=6d1b106104094c73bf8287fed92a3af6&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ2ODMyMjU4MTcxNTc4ODUwNQ%3D%3D.3-ccb7-5&oh=00_AYF_BZu-UIpduCNMSIG2TCUWMRwcA5ckeL3_W0Gilq10nQ&oe=67D67DE4&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/461620572_860083192880350_4458335109680484303_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=110&_nc_oc=Q6cZ2AF8MTe5ASX1AyPnDEL2pdao9NQmwB9G4grA_dNpOxMmfw_VAdmEtdQ2covPdaSQmKU&_nc_ohc=Hw38omI_hooQ7kNvgHKvNRr&_nc_gid=1c9ed1dcd540423b9d7572fbc08e5831&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ2Nzk0NjIzMjc4MjE5Mzk0Ng%3D%3D.3-ccb7-5&oh=00_AYFRGzz1Mu2upJ28uRKOqPUcQOfrWPpSTQlYnBDOGW2AHQ&oe=67D6734D&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/461441007_1065187608672733_2829496885288413639_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AFT9ZWUZxFWVxSVcFHJJx6V4wOoFP0a_AnaZu5HeMH1j7F3OQH63WuBE8YloZW84hA&_nc_ohc=UuzyWoo6uPoQ7kNvgFIurr8&_nc_gid=d48528dedde848aa874239b76c029910&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ2NjQ4OTA4MjE3MjAyNDIwMQ%3D%3D.3-ccb7-5&oh=00_AYG_UjFSYzQOQQTQt9iYiQW6Za5NUKDVblGVtjaCGNcnYQ&oe=67D68DB8&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/459165551_1254193352269549_2162248169679659831_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AHXN_X3L4bgBn-8-BMfmet1MGQ9IozMlh-nLyLw81U59Lo32RfN3rnXp_du4Oyiy50&_nc_ohc=h3VBdVj4mccQ7kNvgGDVVns&_nc_gid=38396dabc0854205a02dacb940721057&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQ1NTk3NDMzMDA2ODk2MTYzMw%3D%3D.3-ccb7-5&oh=00_AYE-cN7x1NEu7-y7WSqS1mCiurerEsc1ePRP1crUuEAUpg&oe=67D689C5&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t39.30808-6/472681279_18485599588046130_6457564049580845546_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYzMDgwOC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AEspHRhzVnYaqGmHKpPfxgzJzfOrVS0p09zLE5y-RR-zPIF4Yps1v3NDnUeX5CWIpc&_nc_ohc=tHNWvcPnUsgQ7kNvgFvk-ZQ&_nc_gid=3bb9b8fbfb45442a825ef2d05fcdfde5&edm=ALQROFkAAAAA&ccb=7-5&ig_cache_key=MzQ0OTAyMzcwNDc4NjgwOTU1MA%3D%3D.3-ccb7-5&oh=00_AYF_Moxv_K19Yi7CxZwFSW7Bj0P7IKt3ybQ8aVrsH_adEg&oe=67D66432&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/454380156_369304342874143_9198834646683537064_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=107&_nc_oc=Q6cZ2AEPSdzaTaW8t0qF-jlbAxZsC8Phu9tohI-mR3RzxcF5HX75LwaGl9y5HLeOctogGUA&_nc_ohc=H3pT5CMWIJoQ7kNvgGK_hFp&_nc_gid=52e0f90d7de2494d91eaa1f71d35f839&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQyOTQ2MzYxMTg1MzQ0Mzg4NA%3D%3D.3-ccb7-5&oh=00_AYFAtRHEcgYXLhw4To9hh7O8CbNgTiRUYVJr13yCc8ojrA&oe=67D66A17&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t39.30808-6/454374481_18456960262003309_4354368622218960935_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYzMDgwOC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AH0zuSY5n10VX98q2KBV6HOiZ35Gr5vEzdlguciodYhYa2ZF-vYiZb-qPOQQK9ngvI&_nc_ohc=-mgFKLHoY4oQ7kNvgEG4sMg&_nc_gid=2130ad57a3f54cf0ae1c24e471656487&edm=ALQROFkAAAAA&ccb=7-5&ig_cache_key=MzQyODE1NzYxMjIwODIzNTM1NA%3D%3D.3-ccb7-5&oh=00_AYH2Axm226Hby-Iy9uRPw669SM31TqGWbxuNQ7bYOc_ikA&oe=67D68C44&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/453911880_1098756048525903_5061759028029477028_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=103&_nc_oc=Q6cZ2AEo52LAnvGrwYJQve8WAaJGtpoPrhflTFgdb2Je5vB0oldFff1-HmnaEYVitBSX-DE&_nc_ohc=0wXBvOdlLigQ7kNvgEUpk-F&_nc_gid=99ae12c56b5140ba8bf2c17875f6510a&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQyNTI5NjY0NTk5MzY1OTEwMQ%3D%3D.3-ccb7-5&oh=00_AYHuTDH0mHlPWKRQMqhv9YsdofvTMGpfWpm2IC6So63abg&oe=67D6844C&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/450677003_1193422085033127_6434473055579057041_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMDgweDEwODAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=103&_nc_oc=Q6cZ2AGbi8FoV_hpeUD_9p_vCpwb9SDkNdOd6ZNiXDCpFdfipP5eATK_bofodysWWc86DV0&_nc_ohc=y9XymH6Jy7UQ7kNvgFs72zj&_nc_gid=299afbf870b54f27a71fac876e13cd80&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQyNDI3NzgwNzkwMDA0MDE1Mg%3D%3D.3-ccb7-5&oh=00_AYE4yqiHhSGDTd_paSKFtCaETOssWVMyd2xrF_ILssGTCg&oe=67D68CB4&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/453448704_2538152896372084_4947168412569382334_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AHQG0_z3IEWRwWSyvB9ETGCjOTlfvEdsBRSy_hWaf43UvN3nuUfDlbkXaMC47cZqDg&_nc_ohc=m0Qfija_JsUQ7kNvgE1g44L&_nc_gid=4d77a43960114680ad157b8444f7c08b&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQyMzU1OTcxNzczMDAzMjczNw%3D%3D.3-ccb7-5&oh=00_AYHwDkNVeAD2g4NHsWyg3xiEyvy0wdcWU3iS4zgwqQe5yA&oe=67D66180&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/451724119_1182399186217535_1570823458508990760_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=111&_nc_oc=Q6cZ2AEHaCavkWbdnjRFy8be-gQKAPS3lLPmjPZ642I35cctAxZWPn9D3pLfrsPMcL3s5Fo&_nc_ohc=XoiiRObttR8Q7kNvgFclexJ&_nc_gid=7c3b78cd968d40db8875ddeb4289e57a&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQxMzU4NTgzNTAyOTUyOTQ4Mw%3D%3D.3-ccb7-5&oh=00_AYEtMJe_nIaKZKmiJdrx4n9UkBLRKi2MekhKk-wMIjGs2g&oe=67D6732C&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/450351443_362403459963209_3320562182601499112_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=105&_nc_oc=Q6cZ2AE2nJH_O0Z4rkaoOQGg4Q-7XMsmn9dhuwIaL6tQpbookWBqm_VmWstDjzQ08e3Qpmg&_nc_ohc=SHJwiL65POwQ7kNvgEys-0h&_nc_gid=6859241deb284956bca5f53c34901cb5&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQwOTE2NjY0NTI5ODUyMTQ1MA%3D%3D.3-ccb7-5&oh=00_AYEnoQKv4TMlTS_DfLVDqopzFnRHWLFZYrQA9nidlxN0cg&oe=67D66EEB&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/449680989_446763564947682_1262966480966991239_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AHqOKTa9TQ-JtzlFuek6LNPFdvUp7evlw2DzQsi0Psr9ngZEGQDOS_PGU58qiqBEUw&_nc_ohc=Yt3lm814ASQQ7kNvgEcZcZk&_nc_gid=4d9fe96b5b834f68b5c09f77fe361032&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQwMzYxNzUzMzEyNjM1NjQzOA%3D%3D.3-ccb7-5&oh=00_AYEtglM8zW0mp5FhBdkzPmz4W1CxPK7UP1xBf8feqjODxQ&oe=67D65CDA&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/449612081_846826793461458_3112513533067913169_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE3OTkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AFoi-niMcIczxASY9oic-pVs8EC_ZDUUB9r312rI2RmOtMiE9UobrokKy8ASeuLIho&_nc_ohc=K1xn_d9FUeQQ7kNvgEXd3w_&_nc_gid=33e07f5e1a054a619bfd82480ba94913&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzQwMjY4NTAxMDMyNzkxMTQ0OA%3D%3D.3-ccb7-5&oh=00_AYEaZC66fw3hSq1jZP8uLOrIBvzek8orhFNw5wAB6jNk0w&oe=67D68575&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/448367778_1129905198299303_8240439586993326652_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=111&_nc_oc=Q6cZ2AEJRxD7cAqC_OQuu5F3bCbY5UWnm01WtkHNsVuND5NsZ3JkxL3YncZomVmi1i95xCY&_nc_ohc=rej-KpQ8GlkQ7kNvgGN99CK&_nc_gid=8f81f82536414ba687d2e658f9d3695f&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM5MTE4MTQyMDkxMDgzNTcxOQ%3D%3D.3-ccb7-5&oh=00_AYGAbsJupsSRabCbaXg6mHOFJTcQmGtarPo_NfYJdx_B2w&oe=67D68503&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/448267119_1419128125456380_3799889497034245966_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ3eDE2Nzkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=100&_nc_oc=Q6cZ2AEmtyJeFLiCSMZCJlJLo7mhSIwe9iDnTZn2eLs1BWvofd345jAfU4sAzHv5DjH6M7Q&_nc_ohc=XpFogUgxWe8Q7kNvgEbPziy&_nc_gid=976a700868b64ed1882f01b36f76bb6b&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM5MDI4NjE0MDQwMzE4MTE2MQ%3D%3D.3-ccb7-5&oh=00_AYHfrwy-DgUn-3O_lXeSsPxYI1yyPkmMEu6B0qZjVTM5Nw&oe=67D66D6E&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/448333067_385724257831028_1333286387246728927_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDEwNjUuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=108&_nc_oc=Q6cZ2AHAJQmaTRKqwytza5TQgjfqi01Ku1YjA_Rc53ClK6pQejXdhLi3ScBbn5lRtbUmeUY&_nc_ohc=rn7wO71SC3MQ7kNvgGn3LtN&_nc_gid=d74d70d39a0145b4bd25f4eccad804ab&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM4OTg0ODQzNjgzOTU3OTk0NA%3D%3D.3-ccb7-5&oh=00_AYEoDloINy06569BUnT8zlR7OF_oRwdhYaKvVTngIL0VjQ&oe=67D66D0E&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/447783505_348367911327138_1306649976445950188_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=106&_nc_oc=Q6cZ2AEymf5PChps325XGATxTvoJ6lgxBzOFUxNBoz-FhMR7v71u_htmsa4R_JdiEpaXN8c&_nc_ohc=o5mh8xzTQLgQ7kNvgF9WoWG&_nc_gid=ac120fa14c5546059c0f56739c62a6b4&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM4NDU3OTk5NzQ3MjQ3MTI0OA%3D%3D.3-ccb7-5&oh=00_AYHIlMSywjPCycCXa0fA3nKuqic7iBVPEp0Led91dtSrdg&oe=67D680AD&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/446196076_1365723171487141_4595334253327349802_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=101&_nc_oc=Q6cZ2AFIdousvQP6gM_FgiO_AtbJTQSzZkruiOH7Rlel4x85NEMKHX6jOkVfcRKiGzvnMkc&_nc_ohc=JHNYYN_rx04Q7kNvgE1yW-v&_nc_gid=739dbd70fed24d71abb8590b58d5e7e9&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM3NTk4NDA1NTEyNjk5NjgwNA%3D%3D.3-ccb7-5&oh=00_AYG9Jn2X6YVD1pMpiCC8q4GK7k88iV4aO8-O0Vvtnm4SlA&oe=67D681D6&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/445427845_713699974101508_7628168043699394583_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AEE4q-Sw494RV2Uj4nLSHzUcYtgi8cl8HtRu5VtUcXX5h72J5sAkER6YDLbFqB3z10&_nc_ohc=zzbG9FNrm_AQ7kNvgF2YxYg&_nc_gid=371a303042814a93ad6e031e3082aee9&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM3Mzc0ODY5MTU4MTA0MDMyMA%3D%3D.3-ccb7-5&oh=00_AYEFnBczSOjJmNq7-HYNc0rgtM4kWk5b89qsGznsY0oLXw&oe=67D68184&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/444815839_467885772434978_2963514583726358323_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=102&_nc_oc=Q6cZ2AGk9jN-2NGiGi7P9QNQqD4CcVKYEwr7PzzIWgpDWle0DJ093Nrz_45DXBHhAAnOBNE&_nc_ohc=zjLWIR2zqiMQ7kNvgFjOEpC&_nc_gid=af2535c5364a4cb8b6b8c0856bd4c623&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM3MzU1NTg5MzYzNjY2MTg0NQ%3D%3D.3-ccb7-5&oh=00_AYGP9PTo_COUjhuKU787Po4FPl3w92sCkB8BDCCyg2uW5g&oe=67D689F5&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/445427846_1210415126642551_4132775855881180339_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=107&_nc_oc=Q6cZ2AHQePjcmAj89OAgTO9BoZXn17DZhV6l93YE5VqebwlWuALQcRKA-lMnfhynhhtOxlA&_nc_ohc=k56INSg3J6QQ7kNvgG-e3Qw&_nc_gid=bb7093f5da364b219acd85d14fe449d3&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM3Mjk5MzE3MjU4Mjk2Nzk2MQ%3D%3D.3-ccb7-5&oh=00_AYGt4a0R7YclSYlF2skozwkcFqdTTWkugbbMATWU9hZpLQ&oe=67D683D1&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams2-1.cdninstagram.com/v/t51.29350-15/444734571_427978569988588_7830641598183736873_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE4MDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams2-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AEyF_DMXDlLeH3xfPhxcbospVrCWPXGjYl6fW9S3As4oW80_8LWxtATSvPUPvCHzX4&_nc_ohc=gTnr49uIvAIQ7kNvgHk1p6m&_nc_gid=4d859cde1a5f4f2a88b0817de5e1ebc7&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM3MjMwNjc0NzkxNTA2MTAzNg%3D%3D.3-ccb7-5&oh=00_AYHNHqivk0_9iFBH8VFh9wuN6dN6mFDDmPTzlSWJZCuj9Q&oe=67D683F0&_nc_sid=fc8dfb
# Image downloaded successfully
# https://scontent-ams4-1.cdninstagram.com/v/t51.29350-15/436402609_1129069068418310_2901365611794212219_n.jpg?stp=dst-jpg_e35_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE2NDguc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-ams4-1.cdninstagram.com&_nc_cat=102&_nc_oc=Q6cZ2AFfhGyT6iNFSFz472Y3I7NnVY5JvvD1wT3kkXzN3DoqSKdgDEKFbTGXdsrwj71OkuI&_nc_ohc=5K4KqNhBR1YQ7kNvgHwjqAB&_nc_gid=01673fbc57ae41c2968fb7c233f672e0&edm=ALQROFkBAAAA&ccb=7-5&ig_cache_key=MzM2NjU5NTc4OTMxMjQ1MzAzMA%3D%3D.3-ccb7-5&oh=00_AYE4d6sR594tkl4rgxIl3ltj9kPz4Bno4H8AJm3duYVt7A&oe=67D68DE2&_nc_sid=fc8dfb
# Image downloaded successfully
#             Influencer                                           Post URL  \
# 200  realbarbarapalvin  https://www.instagram.com/realbarbarapalvin/p/...
# 50        maralafontan  https://www.instagram.com/maralafontan/p/DHB1u...
# 201  realbarbarapalvin  https://www.instagram.com/realbarbarapalvin/p/...
# 51        maralafontan  https://www.instagram.com/maralafontan/p/DG-9I...
# 150         badgalriri  https://www.instagram.com/badgalriri/p/DG9YvUn...
#
#                         Image Name      Likes           Date Time  \
# 200  realbarbarapalvin_image_0.jpg     52,361 2025-03-11 18:38:18
# 50        maralafontan_image_0.jpg     10,515 2025-03-10 18:23:08
# 201  realbarbarapalvin_image_1.jpg            2025-03-09 16:28:12
# 51        maralafontan_image_1.jpg     13,795 2025-03-09 15:30:09
# 150         badgalriri_image_0.jpg  8,847,761 2025-03-09 00:52:54
#
#                                               Metadata
# 200  52K likes, 211 comments - realbarbarapalvin on...
# 50   11K likes, 73 comments - maralafontan on March...
# 201  realbarbarapalvin on March 9, 2025: "a V speci...
# 51   14K likes, 66 comments - maralafontan on March...
# 150  9M likes, 38K comments - badgalriri on March 8...

# %% [markdown]
# ## CREATING CAPTION but split the emoji and text

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    --------------------------------------- 590.6/590.6 kB 20.5 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1
# ✅ Extracted data saved to scrapping_dmi.xlsx

# %%
import pandas as pd
import emoji
import re

# Load the Excel file
file_path = "scrapping_dmi.xlsx"
df = pd.read_excel(file_path)

def convert_to_number(value):
    """
    Converts a string representation of numbers with 'K' (thousands) or 'M' (millions)
    into actual numeric values.
    """
    if pd.isna(value) or not isinstance(value, str):
        return None

    value = value.replace(",", "").strip()

    if value.lower() == "not found":
        return None

    try:
        if "K" in value.upper():
            return float(value.replace("K", "").replace("k", "")) * 1_000
        elif "M" in value.upper():
            return float(value.replace("M", "").replace("m", "")) * 1_000_000
        else:
            return float(value)
    except ValueError:
        return None

def get_comments(metadata):
    """
    Extracts the number of comments from metadata string.
    Example:
        "8,706 likes, 31 comments - ..." -> 31
    """
    if not isinstance(metadata, str):
        return None

    match = re.search(r"([\d,\.KM]+)\s+comments", metadata, re.IGNORECASE)
    if match:
        return convert_to_number(match.group(1))

    return None

def get_caption_manual(metadata):
    """
    Extracts the first quoted text after a colon (:), ensuring only plain text remains.
    Example:
        'username on March 6, 2025: "😛me gusta🍭 @desigual Collaboration commerciale"'
        -> "me gusta @desigual Collaboration commerciale"
    """
    if not isinstance(metadata, str):
        return None

    # Find the first occurrence of : "
    start_idx = metadata.find(': "')
    if start_idx == -1:
        return None

    # Advance to the first character after : "
    start_quote = start_idx + len(': "')

    # Find the ending quote
    end_quote = metadata.find('"', start_quote)
    if end_quote == -1:
        return None

    # Extract everything inside the quotes
    caption = metadata[start_quote:end_quote].strip()

    # Remove emojis from caption
    caption_no_emoji = "".join(char for char in caption if char not in emoji.EMOJI_DATA)

    return caption_no_emoji.strip()

def extract_emojis(text):
    """
    Extracts all emojis from a given text and counts their occurrence.
    """
    if not isinstance(text, str):
        return "", 0

    emojis = [char for char in text if char in emoji.EMOJI_DATA]
    return "".join(emojis), len(emojis)

# Apply comment counting functions
df["Number of Comments"] = df["Metadata"].apply(get_comments)

# Apply extraction functions
df["Caption"] = df["Metadata"].apply(get_caption_manual)

# Extract emojis separately from the original Caption before removing emojis
df["Emoji Use"], df["Emoji Number"] = zip(*df["Metadata"].apply(lambda x: extract_emojis(x)))

# Convert Emoji Number column to integer
df["Emoji Number"] = df["Emoji Number"].astype(int, errors="ignore")

# Convert columns to appropriate types
df["Number of Comments"] = df["Number of Comments"].astype(float, errors="ignore")
df["Emoji Number"] = df["Emoji Number"].astype(int, errors="ignore")

# Save the updated dataset
output_file = "scrapping_dmi.xlsx"
df.to_excel(output_file, index=False)
print(f"✅ Extracted data saved to {output_file}")
# Out:
# ✅ Extracted data saved to scrapping_dmi.xlsx

# %% [markdown]
# ## Creating Caption and number of comments columns in the Excel file from the metadata column

# %%
import pandas as pd

# Load the Excel file
file_path = "scrapping_dmi.xlsx"
df = pd.read_excel(file_path)

def convert_to_number(value):
    """
    Converts a string representation of numbers with 'K' (thousands) or 'M' (millions)
    into actual numeric values.

    Args:
        value (str): The number in string format (e.g., "195K", "2.3M", "1,200", "Not found")

    Returns:
        float or None: The numerical equivalent of the input, or None if conversion fails.
    """
    if pd.isna(value) or not isinstance(value, str):
        return None

    # Remove commas and surrounding spaces
    value = value.replace(",", "").strip()

    if value.lower() == "not found":
        return None

    try:
        if "K" in value.upper():
            return float(value.replace("K", "").replace("k", "")) * 1_000
        elif "M" in value.upper():
            return float(value.replace("M", "").replace("m", "")) * 1_000_000
        else:
            return float(value)  # Convert directly if no K or M
    except ValueError:
        return None

def get_comments_manual(metadata):
    """
    Extracts what's after the first comma and before the word "comments".
    In case of K, multiply by 1,000; in case of M, multiply by 1,000,000.

    Example:
        "195K likes, 561 comments - user..."
        -> substring between the comma and "comments": "561"
        "2,557 comments" -> substring: "2,557"
    """
    if not isinstance(metadata, str):
        return None

    # Find the first comma
    idx_comma = metadata.find(',')
    if idx_comma == -1:
        return None

    # Find "comments" after that comma
    lower_meta = metadata.lower()
    idx_comments = lower_meta.find("comments", idx_comma + 1)
    if idx_comments == -1:
        return None

    # Extract the chunk between the comma and "comments"
    raw_substring = metadata[idx_comma + 1: idx_comments].strip()  # e.g. "2,557" or "561" or "2.5M"

    # Convert to uppercase to detect 'K'/'M'
    upper_substring = raw_substring.upper()

    # Remove any commas for numeric conversion
    upper_substring = upper_substring.replace(",", "")

    # Identify multiplier
    multiplier = 1
    if 'K' in upper_substring:
        multiplier = 1_000
        upper_substring = upper_substring.replace('K', '')
    elif 'M' in upper_substring:
        multiplier = 1_000_000
        upper_substring = upper_substring.replace('M', '')

    # Convert to numeric
    try:
        return int(float(upper_substring.strip()) * multiplier)
    except ValueError:
        return None

def get_caption_manual(metadata):
    """
    Extracts the first quoted text after a colon (:).
    e.g., ': "Good to be back at it again 💪"'
    """
    if not isinstance(metadata, str):
        return None

    # Find the first occurrence of : "
    start_idx = metadata.find(': "')
    if start_idx == -1:
        return None

    # Advance to the first character after : "
    start_quote = start_idx + len(': "')

    # Find the ending quote
    end_quote = metadata.find('"', start_quote)
    if end_quote == -1:
        return None

    # Extract everything inside the quotes
    return metadata[start_quote:end_quote].strip()

def extract_metadata(metadata):
    """
    Extracts the number of comments (using our custom comma-to-'comments' logic)
    and the caption from quotes.
    """
    if pd.isna(metadata):
        return None, None

    # 1) Number of Comments
    num_comments = get_comments_manual(metadata)

    # 2) Caption
    caption = get_caption_manual(metadata)

    return num_comments, caption

# Apply extraction function to each row in "Metadata"
df[["Number of Comments", "Caption"]] = df["Metadata"].apply(
    lambda x: pd.Series(extract_metadata(x))
)

# Convert "Likes" to numeric (using K/M logic), if the column exists
if "Likes" in df.columns:
    df["Likes"] = df["Likes"].apply(convert_to_number)

# Ensure "Number of Comments" is float (though we already return an int from get_comments_manual)
df["Number of Comments"] = df["Number of Comments"].astype('float', errors='ignore')

# Save the updated dataset
output_file = "scrapping_dmi.xlsx"
df.to_excel(output_file, index=False)
print(f"✅ Extracted data saved to {output_file}")
# Out:
# ✅ Extracted data saved to scrapping_dmi.xlsx

# %% [markdown]
# ## Next, create the Extract Time column in the same format as the Date Time column, formatted as 04/03/2025 21:00:00, to indicate when you extract the data. Copy this to all rows in the Excel file.
#
# ## Next, we can determine how many seconds have elapsed since posting the content until extracting the data.

# %%
import pandas as pd

# Load the dataset
file_path = "scrapping_dmi.xlsx"
df = pd.read_excel(file_path)

# 1) Convert "Date Time" and "Extract Time" to datetime objects
#    using dayfirst=True 
df['Date Time'] = pd.to_datetime(df['Date Time'], format="%d/%m/%Y %H:%M")
df['Extract Time'] = pd.to_datetime(df['Extract Time'], format="%d/%m/%Y %H:%M")

# 2) Calculate the time difference in **seconds** 
df['Seconds Passed'] = (df['Extract Time'] - df['Date Time']).dt.total_seconds()

# 3) Convert the datetime columns back to a string format "DD/MM/YYYY HH:MM:SS"
#    so they look like "04/03/2025 21:00:00" in your Excel file.
df['Date Time'] = df['Date Time'].dt.strftime("%d/%m/%Y %H:%M:%S")
df['Extract Time'] = df['Extract Time'].dt.strftime("%d/%m/%Y %H:%M:%S")

# Save the updated dataset to Excel
output_file = "scrapping_dmi.xlsx"
df.to_excel(output_file, index=False)
print(f"✅ Extracted data (in seconds) saved to {output_file}")
# Out:
# ✅ Extracted data (in seconds) saved to scrapping_dmi.xlsx

# %% [markdown]
# ## Finally, you can manually enter the number of followers, following, posts, and the bio for each influencer into the Excel file.

# %% [markdown]
# ## Feature Extraction

# %%
# Import necessary libraries
import numpy as np  # For numerical operations
import cv2  # OpenCV library for image processing
import matplotlib.pyplot as plt  # Matplotlib for displaying images in Jupyter

# Function to analyze color properties of a photograph
def color_photography(img_path):
    """
    Analyzes the color properties of an image.

    Parameters:
    img_path (str): Path to the image file.

    Returns:
    tuple: Contains brightness, saturation, brightness contrast, and warmth metrics of the image.
    """
    # Load the image from the given path
    img = cv2.imread(img_path)
    
    # Check if the image was loaded successfully
    if img is None:
        raise ValueError(f"Image at path '{img_path}' could not be loaded.")
    
    # Convert the image from BGR to RGB color space for displaying with matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Display the RGB image and its channels
    plt.figure(figsize=(10, 4)) # Set the figure size for the plot 
    
    # Display the original RGB image
    plt.subplot(1, 4, 1) # Create a subplot with 1 row, 4 columns, and index 1
    plt.imshow(img_rgb)
    plt.title('Original Image')
    plt.axis('off')
    
    # Display the Red channel
    plt.subplot(1, 4, 2)
    plt.imshow(img_rgb[:, :, 0], cmap='gray') # for img_rgb, first dimension is height, second dimension is width, and third dimension is the color channel
    plt.title('Red Channel')
    plt.axis('off')
    
    # Display the Green channel
    plt.subplot(1, 4, 3)
    plt.imshow(img_rgb[:, :, 1], cmap='gray')
    plt.title('Green Channel')
    plt.axis('off')
    
    # Display the Blue channel
    plt.subplot(1, 4, 4)
    plt.imshow(img_rgb[:, :, 2], cmap='gray')
    plt.title('Blue Channel')
    plt.axis('off')
    
    plt.show()
    
    # Convert the image from BGR to HSV color space
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV).astype(float) / 255  # normalizing to make the operations scale-independent and makes the values easier to interpret
    #Each channel can have a different range (e.g., Hue in [0, 360] degrees, Saturation, and Value in [0, 1]). By normalizing all values to [0, 1], you create a uniform representation that simplifies further processing
    
    # Display the HSV image and its channels
    plt.figure(figsize=(10, 4))
    
    # Display the Hue channel
    plt.subplot(1, 3, 1)
    plt.imshow(hsv[:, :, 0], cmap='hsv')
    plt.title('Hue Channel')
    plt.axis('off')
    
    # Display the Saturation channel
    plt.subplot(1, 3, 2)
    plt.imshow(hsv[:, :, 1], cmap='gray')
    plt.title('Saturation Channel')
    plt.axis('off')
    
    # Display the Value channel
    plt.subplot(1, 3, 3)
    plt.imshow(hsv[:, :, 2], cmap='gray')
    plt.title('Value Channel')
    plt.axis('off')
    
    plt.show()
    
    # Get the dimensions of the image
    x2, y2 = hsv.shape[:2]  
    
    # Print the dimensions of the image
    print(f"Original Image Dimensions: {x2} x {y2}")
    
    # resize the image to 256x256
    hsv = cv2.resize(hsv, (256, 256))
    
    x2, y2 = hsv.shape[:2] 
    
    # Print the dimensions of the resized image
    print(f"Original Image Dimensions: {x2} x {y2}")

    

    # Calculate the average brightness (value channel in HSV)
    brightness = np.mean(hsv[:, :, 2])
    
    # Calculate the average saturation (saturation channel in HSV)
    saturation = np.mean(hsv[:, :, 1])
    
    # Calculate the contrast of brightness (standard deviation of value channel)
    brightness_contrast = np.std(hsv[:, :, 2])
    
    # Calculate the warmth (percentage of pixels with hue corresponding to warm colors)
    warmth = np.sum((hsv[:, :, 0] < 30/360) | (hsv[:, :, 0] > 110/360)) / (x2 * y2) 
    
    # Return the calculated metrics
    return brightness, saturation, brightness_contrast, warmth

# Example usage in Jupyter Notebook:
# Provide the path to an image file and call the function
img_path = 'scrapping_dmi/badgalriri_image_17.jpg'  # Replace with your image file path
try:
    # Call the function and store the results
    brightness, saturation, brightness_contrast, warmth = color_photography(img_path)
    
    # Display the results
    print(f"Brightness: {brightness}")
    print(f"Saturation: {saturation}")
    print(f"Brightness Contrast: {brightness_contrast}")
    print(f"Warmth: {warmth}")
except ValueError as e:
    # Handle the case where the image could not be loaded
    print(e)
# Out:
# Original Image Dimensions: 1687 x 1350
# Original Image Dimensions: 256 x 256
# Brightness: 0.39311592873487183
# Saturation: 0.35166665886154436
# Brightness Contrast: 0.33910457114431136
# Warmth: 0.8509521484375

# %%
###################
#  IMPORTS
###################
import os                 # For interacting with the operating system (paths, directories)
import glob               # For file pattern matching (e.g., searching for *.jpg)
import numpy as np        # For numerical operations
import cv2                # OpenCV for image handling and processing
import pandas as pd       # For creating and saving data to Excel files

# Hugging Face / PyTorch imports
import torch
from transformers import DetrForObjectDetection, DetrImageProcessor
from PIL import Image     # PIL (Pillow) for handling image files in Python

###################
#  COLOR ANALYSIS
###################
def color_photography(img_path):
    """
    Analyzes the color properties of an image.

    Parameters:
        img_path (str): Path to the image file.

    Returns:
        tuple: (brightness, saturation, brightness_contrast, warmth)
    """
    # Load the image with OpenCV (returns BGR format by default)
    img = cv2.imread(img_path)
    
    # Check if the image was loaded successfully
    if img is None:
        raise ValueError(f"Image at path '{img_path}' could not be loaded.")

    # Convert the image from BGR to HSV color space
    # and normalize the pixel values from [0, 255] to [0, 1] for easier calculations
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV).astype(float) / 255.0 
    
    # Retrieve original dimensions (height x width)
    x2, y2 = hsv.shape[:2] 
    print(f"Original Image Dimensions: {x2} x {y2}")
    
    # Resize the image to 256x256 (this is optional but helps to standardize analysis)
    hsv = cv2.resize(hsv, (256, 256))
    
    # Print the new dimensions after resizing
    x2, y2 = hsv.shape[:2]
    print(f"Resized Image Dimensions: {x2} x {y2}")

    # 1) Calculate brightness as the mean of the Value (V) channel in HSV
    brightness = np.mean(hsv[:, :, 2])
    
    # 2) Calculate saturation as the mean of the Saturation (S) channel
    saturation = np.mean(hsv[:, :, 1])
    
    # 3) Calculate brightness contrast (standard deviation of the Value channel)
    brightness_contrast = np.std(hsv[:, :, 2])
    
    # 4) Calculate "warmth" as the fraction of pixels whose Hue falls
    #    within a certain range (example: < 30° or > 110°, normalized).
    warmth = np.sum((hsv[:, :, 0] < 30/360) | (hsv[:, :, 0] > 110/360)) / (x2 * y2) 
    
    # Return these metrics as a tuple
    return brightness, saturation, brightness_contrast, warmth


def analyze_images_and_save_to_excel(
    folder_path='scrapping_dmi', 
    output_excel='color_analysis_results.xlsx'
):
    """
    Loops through all .jpg images in the given folder,
    computes color metrics, and saves results to an Excel file.
    
    Parameters:
        folder_path (str): Path to the folder containing .jpg images.
        output_excel (str): Name of the output Excel file.
    """
    # Find all .jpg files in the specified folder
    image_files = glob.glob(os.path.join(folder_path, '*.jpg'))
    
    # Prepare a list to accumulate the results
    results = []
    
    # Iterate over each .jpg file
    for img_file in image_files:
        try:
            # Compute color analysis metrics
            brightness, saturation, brightness_contrast, warmth = color_photography(img_file)
            
            # Collect the results in a dictionary
            results.append({
                'File Name': os.path.basename(img_file),  # Get just the filename, no path
                'Brightness': brightness,
                'Saturation': saturation,
                'Brightness Contrast': brightness_contrast,
                'Warmth': warmth
            })
        except ValueError as e:
            # If there's an issue (e.g., file not loaded), print the error and continue
            print(e)
    
    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(results, columns=[
        'File Name', 
        'Brightness', 
        'Saturation', 
        'Brightness Contrast', 
        'Warmth'
    ])
    
    # Save the DataFrame to an Excel file
    excel_path = os.path.join(folder_path, output_excel)
    df.to_excel(excel_path, index=False)
    print(f"Color analysis saved to: {output_excel}")


###################
#  OBJECT DETECTION (DETR)
###################
def load_detr_model():
    """
    Loads the DETR model and processor from Hugging Face.
    
    Returns:
        model (DetrForObjectDetection): The DETR object detection model.
        processor (DetrImageProcessor): Preprocessing utilities for DETR.
    """
    # Load the pre-trained DETR model from huggingface.co
    model = DetrForObjectDetection.from_pretrained("facebook/detr-resnet-50")
    # Load the corresponding image processor to prepare inputs for DETR
    processor = DetrImageProcessor.from_pretrained("facebook/detr-resnet-50")
    return model, processor


def analyze_image_detr(model, processor, image_path):
    """
    Runs object detection on a single image using DETR.
    
    Parameters:
        model (DetrForObjectDetection): The DETR object detection model.
        processor (DetrImageProcessor): The DETR image processor.
        image_path (str): Path to the image file.

    Returns:
        filtered_scores (Tensor): The confidence scores for the detections kept.
        filtered_labels (Tensor): The class label IDs for the detections kept.
    """
    # Open the image with Pillow in RGB mode
    image = Image.open(image_path).convert("RGB")
    
    # Use the processor to convert the image into a form suitable for the model
    inputs = processor(images=image, return_tensors="pt") # Convert the image to PyTorch tensors
    
    # Run the model
    outputs = model(**inputs) # Pass the inputs to the model

    # outputs.logits has shape [batch_size, num_queries, num_classes+1]
    # Apply softmax to convert logits to probabilities
    probas = outputs.logits.softmax(-1) # Apply softmax along the last dimension 
    
    # Get the highest probability for each query (skip the last class which is "no object")
    scores, labels = probas[..., :-1].max(-1) # Get the maximum value along the last dimension (class dimension)

    # We choose a confidence threshold (e.g. 0.75) to filter out low-confidence detections
    filtered_indices = scores >= 0.60
    filtered_scores = scores[filtered_indices]
    filtered_labels = labels[filtered_indices]

    return filtered_scores, filtered_labels


def analyze_folder_detr(
    folder_path='scrapping_dmi', 
    output_excel='detr_object_detection_results.xlsx'
):
    """
    Loops through images in a folder, runs DETR object detection,
    and saves results to an Excel file.

    Parameters:
        folder_path (str): Folder containing image files (.jpg, .png, .jpeg).
        output_excel (str): Name of the Excel file to save results.
    """
    # Load the DETR model and its processor
    model, processor = load_detr_model()
    
    # The model config has mappings from label IDs to label names
    config = model.config
    
    # Gather all image files with .png, .jpg, or .jpeg extensions
    image_files = [
        f for f in os.listdir(folder_path) 
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ]
    
    # This list will store dictionaries of results
    results_list = []
    
    for image_file in image_files:
        # Construct the full path to the image
        full_path = os.path.join(folder_path, image_file)
        
        # Get the detection scores and label IDs from DETR
        scores, labels = analyze_image_detr(model, processor, full_path)
        
        # Convert numeric label IDs to their string names
        label_names = []
        unique_objects = set()
        
        for label in labels:
            # Retrieve the label name from config using the label ID
            label_name = config.id2label[label.item()] 
            label_names.append(label_name)
            unique_objects.add(label_name)
        
        # Build a dictionary of the object detection results for this image
        results_list.append({
            "File Name": image_file,
            "Total Detected Objects": len(label_names),
            "Number of Unique Objects": len(unique_objects),
            "All Label Names": ", ".join(label_names),
            "Unique Label Names": ", ".join(unique_objects)
        })
    
    # Create a DataFrame from the detection results
    results_df = pd.DataFrame(results_list, columns=[
        "File Name",
        "Total Detected Objects",
        "Number of Unique Objects",
        "All Label Names",
        "Unique Label Names"
    ])
    
    # Construct the path for the output Excel file
    excel_path = os.path.join(folder_path, output_excel)
    
    # Save the DataFrame to Excel
    results_df.to_excel(excel_path, index=False)
    print(f"Object detection results saved to: {excel_path}")


###################
#  MAIN
###################
# if __name__ == "__main__":
#     # 1. Run the color analysis on all .jpg images and save results
#     analyze_images_and_save_to_excel(
#         folder_path='scrapping_dmi', 
#         output_excel='color_analysis_results.xlsx'
#     )

#     # 2. Run DETR object detection on all images and save results
#     analyze_folder_detr(
#         folder_path='scrapping_dmi',
#         output_excel='detr_object_detection_results.xlsx'
#     )

# %%
# 1. Run the color analysis
analyze_images_and_save_to_excel(
    folder_path='scrapping_dmi', 
    output_excel='color_analysis_results.xlsx'
)

# 2. Run DETR object detection
analyze_folder_detr(
    folder_path='scrapping_dmi',
    output_excel='detr_object_detection_results.xlsx'
)
# Out:
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1730 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1686 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1214 x 1042
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1195 x 995
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1648 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1657 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1261 x 1020
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1780 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1802 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1458 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1796 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1659 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1491 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1726 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1796 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1796 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1644 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1734 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1473 x 1179
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1784 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1079 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1687 x 1350
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1054 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 617 x 885
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1796 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1796 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1796 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1266 x 1222
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 810 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1080 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1796 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1080 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1080 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1079 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 562 x 750
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1796 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1080 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1178 x 1178
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 753 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 961 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1403 x 1122
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1234 x 1234
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1131 x 1131
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1008 x 806
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1687 x 1350
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 960 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1736 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 640 x 640
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1292 x 1179
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1529 x 1227
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1783 x 1430
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1532 x 1226
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1295 x 1039
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1518 x 1218
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 957 x 768
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1681 x 1345
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1080 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1437 x 1314
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1079 x 1079
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1133 x 1416
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1079 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 867 x 1084
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 940 x 1176
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1028 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1795 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1336 x 1069
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 960 x 768
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1350 x 1080
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 722 x 963
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1333 x 1067
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1350 x 1080
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1350 x 1080
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1350 x 1080
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1798 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1605 x 1284
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1758 x 1407
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1792 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1350 x 1080
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 943 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1681 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1797 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1000 x 800
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1440 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1000 x 800
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1759 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1758 x 1407
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1080 x 1080
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1679 x 1347
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1065 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1648 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1800 x 1440
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1600 x 1280
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1325 x 1060
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 900 x 720
# Resized Image Dimensions: 256 x 256
# Original Image Dimensions: 1799 x 1440
# Resized Image Dimensions: 256 x 256
# Color analysis saved to: color_analysis_results.xlsx
# Some weights of the model checkpoint at facebook/detr-resnet-50 were not used when initializing DetrForObjectDetection: ['model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DetrForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Object detection results saved to: scrapping_dmi\detr_object_detection_results.xlsx

# %% [markdown]
# ## Explore different models that you can use for assignment from huggingface.co
#
# https://huggingface.co/models
#
# https://huggingface.co/facebook/detr-resnet-50
#
# https://huggingface.co/deepseek-ai/DeepSeek-R1

# %% [markdown]
# ## More information about fine-tunning and transfer learning
#
# https://github.com/dariasil/image_tutorial/blob/main/Image%20Analytics%20in%20Marketing%20Code%20Examples-Book%20Chapter.ipynb
#
# https://medium.com/towards-data-science/transfer-learning-from-pre-trained-models-f2393f124751
